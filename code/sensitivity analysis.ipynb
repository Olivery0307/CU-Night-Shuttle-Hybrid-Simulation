# %% [markdown]
# # Set up

# %%
# Install required packages
# !pip3 install openpyxl simpy
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Collecting simpy
#   Downloading simpy-4.1.1-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Downloading simpy-4.1.1-py3-none-any.whl (27 kB)
# Installing collected packages: simpy
# Successfully installed simpy-4.1.1

# %%
# Import libraries
import pandas as pd
import simpy
import numpy as np
import math
from collections import defaultdict
import datetime
import matplotlib.pyplot as plt
import copy
from datetime import datetime, timedelta
import random

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load Excel file
df_supply = pd.read_excel("/content/drive/MyDrive/IEOR 4418 Project/data/CUL October 2025 Supply Plan.xlsx")

# Column mapping based on Excel structure
hour_columns = {
    16: '4p-5p',
    17: '5p-6p',
    18: '6p-7p',
    19: '7p-8p',
    20: '8p-9p',
    21: '9p-10p',
    22: '10p-11p',
    23: '11p-12a',
    0: '12a-1a',
    1: '1a-2a',
    2: '2a-3a',
}

# %%
# Convert to dictionary: {date: {hour: vehicle_count}}
supply_plan = {}

for _, row in df_supply.iterrows():
    # Parse date
    date = pd.to_datetime(row['Date']).date()
    supply_plan[date] = {}

    for hour, col_name in hour_columns.items():
        if col_name in df_supply.columns:
            vehicles = row[col_name]
            # Handle NaN or missing values
            if pd.isna(vehicles):
                vehicles = 16  # Default
            supply_plan[date][hour] = int(vehicles)

print(f"  Loaded supply plan for {len(supply_plan)} dates")
# Out:
#   Loaded supply plan for 31 dates

# %%
# Load via data
df = pd.read_csv("/content/drive/MyDrive/IEOR 4418 Project/data/Ride Requests_2025-11-11-part-2.csv")
df['Request_Time'] = pd.to_datetime(df['Request Creation Time'])
if 'Request Status' in df.columns:
    df = df[df['Request Status'] == 'Completed']
print(f"  Filtered to {len(df)} completed rides")
print(f"  Date range: {df['Request_Time'].min()} to {df['Request_Time'].max()}")
# Out:
#   Filtered to 27257 completed rides
#   Date range: 2025-09-15 19:59:00 to 2025-10-31 23:57:00

# %%
# create total travel time column, which is actual dropoff time - Actual Pickup Time
df['Travel_Time'] = pd.to_datetime(df['Actual Dropoff Time']) - pd.to_datetime(df['Actual Pickup Time'])
df['Wait Time'] = pd.to_datetime(df['Actual Pickup Time']) - pd.to_datetime(df['Request Creation Time'])
df['Travel_Time'] = df['Travel_Time'].dt.total_seconds() / 60
df['Wait_Time'] = df['Wait Time'].dt.total_seconds() / 60
df.head()
# Out:
#   Request Creation Time Request Status  Number of Passengers  \
# 2       9/15/2025 19:59      Completed                     1
# 4       9/15/2025 20:00      Completed                     1
# 5       9/15/2025 20:00      Completed                     1
# 7       9/15/2025 20:00      Completed                     1
# 8       9/15/2025 20:00      Completed                     1
#
#    On Demand Pickup ETA Minutes  Origin Lat  Origin Lng  Destination Lat  \
# 2                          11.9   40.800520  -73.967568        40.813341
# 4                          10.0   40.818184  -73.959134        40.808708
# 5                           9.4   40.817832  -73.958271        40.803711
# 7                          33.7   40.816860  -73.960385        40.809748
# 8                          16.6   40.805243  -73.954770        40.800588
#
#    Destination Lng Actual Pickup Time Actual Dropoff Time        Request_Time  \
# 2       -73.961237    9/15/2025 20:18     9/15/2025 20:32 2025-09-15 19:59:00
# 4       -73.958553    9/15/2025 20:16     9/15/2025 20:30 2025-09-15 20:00:00
# 5       -73.964770    9/15/2025 20:15     9/15/2025 20:26 2025-09-15 20:00:00
# 7       -73.959489    9/15/2025 20:36     9/15/2025 20:42 2025-09-15 20:00:00
# 8       -73.968130    9/15/2025 20:26     9/15/2025 20:36 2025-09-15 20:00:00
#
#    Travel_Time       Wait Time  Wait_Time
# 2         14.0 0 days 00:19:00       19.0
# 4         14.0 0 days 00:16:00       16.0
# 5         11.0 0 days 00:15:00       15.0
# 7          6.0 0 days 00:36:00       36.0
# 8         10.0 0 days 00:26:00       26.0

# %%
# avg
avg_travel_time = df['Travel_Time'].mean()
avg_wait_time = df['Wait_Time'].mean()
print(f"  Average travel time: {avg_travel_time:.2f} minutes")
print(f"  Average wait time: {avg_wait_time:.2f} minutes")
# Out:
#   Average travel time: 8.97 minutes
#   Average wait time: 23.64 minutes

# %%
def get_service_date_and_hour(dt):
    """Map a datetime to the service date and hour."""
    if dt.hour >= 18:  # 6 PM onwards - same day
        return dt.date(), dt.hour
    elif dt.hour < 3:  # Midnight to 3 AM - previous day's service
        return (dt - timedelta(days=1)).date(), dt.hour
    else:
        return None, None  # Outside service hours


# Apply the function and create separate columns properly
service_info = df['Request_Time'].apply(get_service_date_and_hour)
df['service_date'] = service_info.apply(lambda x: x[0])
df['service_hour'] = service_info.apply(lambda x: x[1])

df_service = df[df['service_date'].notna()].copy()
print(f"  Requests during service hours (before filtering): {len(df_service)}")
print(f"  Ride data date range: {df_service['service_date'].min()} to {df_service['service_date'].max()}")
print(f"  Supply plan date range: {min(supply_plan.keys())} to {max(supply_plan.keys())}")

# Filter to only dates in supply plan (October 2025)
supply_min_date = min(supply_plan.keys())
supply_max_date = max(supply_plan.keys())
df_service = df_service[(df_service['service_date'] >= supply_min_date) &
                        (df_service['service_date'] <= supply_max_date)].copy()

print(f"  Requests after filtering: {len(df_service)}")
print(f"  Filtered date range: {df_service['service_date'].min()} to {df_service['service_date'].max()}")
# Out:
# Filtering to service hours (6 PM - 3 AM)...
#   Requests during service hours (before filtering): 27093
#   Ride data date range: 2025-09-15 to 2025-10-31
#   Supply plan date range: 2025-10-01 to 2025-10-31
#
#   ✅ Filtered to supply plan dates (October 2025)
#   Requests after filtering: 18286
#   Filtered date range: 2025-10-01 to 2025-10-31

# %%
# Define corner grid (streets and avenues)
# streets = [103, 106, 110, 113, 116, 120, 122, 125, 129, 133,135] #list(range(103, 136,3))
streets = list(range(103, 137,2))
avenues = {
    "Riverside": -73.9704,
    "Broadway": -73.9626,
    "Amsterdam": -73.9656,
    "Morningside": -73.9586,
    "StNicholas": -73.9498
}

def street_to_lat(st):
    return (st - 100)*0.0009 + 40.800

corners = []
for st in streets:
    lat = street_to_lat(st)
    for name, lon in avenues.items():
        corners.append((lat, lon))

print(f"Total corners defined: {len(corners)}")
# Out:
# Total corners defined: 85

# %% [markdown]
# # Config & Helper Function

# %%
# Configuration
MAX_WALK_MIN = 3.0
SPEED_MPS = 3.57 #8mph
DWELL_TIME_SEC = 90
DISPATCH_FRICTION_SEC = 60

def haversine_m(p1, p2):
    lat1, lon1 = p1
    lat2, lon2 = p2
    R = 6371000
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dl = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dl/2)**2
    return R * 2 * math.atan2(math.sqrt(a), math.sqrt(1-a))

def get_nearest_corner(point, corners):
    dists = [haversine_m(point, c) for c in corners]
    min_idx = int(np.argmin(dists))
    return corners[min_idx], dists[min_idx]

def calibrated_travel_time(p1, p2, is_corner_trip=False):
    dist = haversine_m(p1, p2)

    if is_corner_trip:
        effective_dist = dist * 1.1
        effective_speed = SPEED_MPS * 1.2
    else:
        effective_dist = dist * 1.3
        effective_speed = SPEED_MPS

    base_time = effective_dist / effective_speed

    # Add Traffic Light
    num_blocks = dist / 250  # NYC blocks are ~250m
    num_lights = num_blocks  # Not every intersection has lights
    avg_red_wait = 30  # Average wait when hitting a red light
    prob_red = 0.3  # 30% chance of hitting red

    traffic_light_delay = num_lights * avg_red_wait * prob_red

    # REALISM ADDITION: Traffic Variability
    # 70% of time: Normal traffic (0-10% delay)
    # 20% of time: Moderate traffic (20-50% delay)
    # 10% of time: Bad congestion (50-200% delay)
    rand = random.random()
    if rand < 0.7:
        congestion_factor = random.uniform(1.0, 1.1)
    else:
        congestion_factor = random.uniform(1.2, 1.5)

    return (base_time * congestion_factor) + traffic_light_delay

def calculate_route_time(current_loc, route):
    if not route: return 0
    total = 0
    last = current_loc
    for stop in route:
        lat, lon, _, _ = stop
        target = (lat, lon)
        start_is_corner = last in corners
        end_is_corner = target in corners
        is_avenue_trip = start_is_corner and end_is_corner
        total += calibrated_travel_time(last, target, is_corner_trip=is_avenue_trip)
        total += DWELL_TIME_SEC
        total += DISPATCH_FRICTION_SEC
        last = target
    return total

print("  Helper functions defined")
# Out:
#   Helper functions defined

# %% [markdown]
# # Vehicle Class

# %%
class Vehicle:
    def __init__(self, env, id, start_loc, tracker, max_wait_guarantee=20):
        self.env = env
        self.id = id
        self.tracker = tracker
        self.location = start_loc
        self.capacity = 6
        self.passengers = set()
        self.route = []
        self.active_stop = None
        self.max_wait_guarantee = max_wait_guarantee
        self.action = env.process(self.run())

    def run(self):
        while True:
            if not self.route:
                yield self.env.timeout(1)
                continue

            next_stop = self.route[0]
            target_loc = (next_stop[0], next_stop[1])

            # Batch all stops at same location
            batch = []
            while self.route and (self.route[0][0], self.route[0][1]) == target_loc:
                batch.append(self.route.pop(0))

            # Calculate drive time
            start_is_corner = self.location in corners
            end_is_corner = target_loc in corners
            is_avenue_trip = start_is_corner and end_is_corner

            drive_time = calibrated_travel_time(self.location, target_loc, is_corner_trip=is_avenue_trip)

            # Drive + friction
            yield self.env.timeout(drive_time + DISPATCH_FRICTION_SEC)
            self.location = target_loc

            # Reduced dwell time for fairness
            total_dwell = 60 + (10 * max(0, len(batch) - 1))
            yield self.env.timeout(total_dwell)

            timestamp = self.env.now

            # Process pickups and dropoffs
            for _, _, action, req_id in batch:
                if action == 'pickup':
                    self.passengers.add(req_id)
                    if req_id in self.tracker:
                        actual_wait = (timestamp - self.tracker[req_id]['req_time']) / 60
                        self.tracker[req_id]['pickup_time'] = timestamp
                        self.tracker[req_id]['actual_wait'] = actual_wait
                elif action == 'dropoff':
                    if req_id in self.passengers:
                        self.passengers.remove(req_id)
                        if req_id in self.tracker:
                            self.tracker[req_id]['dropoff_time'] = timestamp

            self.active_stop = None

print("  Vehicle class defined")
# Out:
#   Vehicle class defined

# %% [markdown]
# # Dispatcher

# %%
def check_capacity(initial_load, route, capacity=6):
    """
    Simulates the route to ensure passenger count never exceeds capacity.
    """
    current_load = initial_load
    for _, _, action, _ in route:
        if action == 'pickup':
            current_load += 1
        elif action == 'dropoff':
            current_load -= 1

        # If load ever exceeds capacity, this route is invalid
        if current_load > capacity:
            return False
    return True

def find_best_vehicle_fair(fleet, request, current_time, max_wait_minutes=20):
    best_veh = None
    best_route = None
    min_cost = float('inf')

    p_loc = request['pickup_loc']
    d_loc = request['dropoff_loc']
    rid = request['id']
    req_time = request.get('req_time', 0)

    # Pre-calculate direct distance for cost function
    direct_distance = haversine_m(p_loc, d_loc)

    # Constraints
    MAX_ROUTE_LENGTH = 5
    SAFETY_BUFFER = 1.2  # Multiply estimated travel times by 1.2x for safety

    # COST WEIGHTS
    ALPHA_QUEUE = 5.0
    BETA_WAIT = 4.0
    GAMMA_DETOUR = 3.0

    for v in fleet:
        # Skip full queues
        if len(v.route) > MAX_ROUTE_LENGTH:
            continue

        # Get vehicle current state
        start_node = v.active_stop if v.active_stop else (*v.location, None, None)
        current_pos = (start_node[0], start_node[1])

        # Current route of the vehicle
        curr_route = v.route[:]

        # Try inserting the new request at every valid position
        for i in range(len(curr_route) + 1):
            # Constraint: Dropoff must immediately follow pickup (for simplicity/predictability)
            j = i + 1

            cand = curr_route[:]
            cand.insert(i, (p_loc[0], p_loc[1], 'pickup', rid))
            cand.insert(j, (d_loc[0], d_loc[1], 'dropoff', rid))

            # We simulate the entire route timeline to see if ANYONE gets delayed too much

            valid_assignment = True
            simulated_time = current_time
            last_loc = current_pos

            # Track arrival times for checking constraints
            temp_tracker = {}

            for stop in cand:
                lat, lon, action, stop_req_id = stop
                target = (lat, lon)

                # Travel Time (With Safety Buffer)
                # We use the deterministic base time * safety buffer to prevent "Optimism Bias"
                dist = haversine_m(last_loc, target)
                drive_sec = (dist / SPEED_MPS) * SAFETY_BUFFER

                simulated_time += drive_sec
                simulated_time += DWELL_TIME_SEC + DISPATCH_FRICTION_SEC

                # 2. Check Constraints
                if action == 'pickup':
                    # Record pickup time for this passenger in our temp tracker
                    temp_tracker[stop_req_id] = {'pickup': simulated_time}

                    # Check Wait Time Constraint
                    # Get request time (either from new request or existing vehicle tracker)
                    if stop_req_id == rid:
                        p_req_time = req_time
                    else:
                        p_req_time = v.tracker[stop_req_id]['req_time']

                    wait_min = (simulated_time - p_req_time) / 60
                    if wait_min > max_wait_minutes:
                        valid_assignment = False
                        break

                last_loc = target

            if not valid_assignment:
                continue


            # Calculate metrics for the new passenger for the cost function
            new_pass_pickup_time = temp_tracker[rid]['pickup']
            new_wait_min = (new_pass_pickup_time - req_time) / 60

            # Cost Calculation
            queue_penalty = len(cand) * ALPHA_QUEUE
            wait_penalty = new_wait_min * BETA_WAIT

            # Detour Penalty (Ratio of actual ride distance vs direct)
            ride_distance = haversine_m(p_loc, d_loc)
            detour_penalty = ((ride_distance / max(direct_distance, 1)) - 1.0) * GAMMA_DETOUR

            total_cost = queue_penalty + wait_penalty + detour_penalty

            if total_cost < min_cost:
                min_cost = total_cost
                best_veh = v
                best_route = cand

    return best_veh, best_route

# %% [markdown]
# # Simulation Function(1 hour)

# %%
def run_simulation_for_hour(df_hour, num_vehicles, scenario_mode='hybrid'):
    """
    GUARANTEED SERVICE LEVEL: Every student gets picked up within 20 minutes, period.

    Approach: Spawn overflow vehicles PROACTIVELY based on predicted wait times.
    """
    env = simpy.Environment()
    tracker = {}
    # Start with base fleet
    fleet = [Vehicle(env, i, corners[i%len(corners)], tracker, max_wait_guarantee=20)
             for i in range(num_vehicles)]

    sorted_reqs = df_hour.sort_values('Request_Time')
    hour_start = sorted_reqs['Request_Time'].min()
    hour_start = hour_start.replace(minute=0, second=0, microsecond=0)

    corner_users = 0
    total_users = 0
    overflow_vehicles = []

    # Service Level Agreement
    MAX_WAIT_SLA = 40  # Target: 40 minutes max wait
    MAX_RIDE_SLA = 20  # Target: 20 minutes max ride

    for idx, row in sorted_reqs.iterrows():
        req_time = (row['Request_Time'] - hour_start).total_seconds()

        if req_time > env.now:
            env.run(until=req_time)

        # Prepare request
        origin = (row['Origin Lat'], row['Origin Lng'])
        dest = (row['Destination Lat'], row['Destination Lng'])

        p_corn, p_dist = get_nearest_corner(origin, corners)
        d_corn, d_dist = get_nearest_corner(dest, corners)
        p_walk_min = (p_dist / 1.4) / 60
        d_walk_min = (d_dist / 1.4) / 60

        use_corner = False
        if scenario_mode == 'corner':
            use_corner = True
        elif scenario_mode == 'door':
            use_corner = False
        elif scenario_mode == 'hybrid':
            if (p_walk_min <= MAX_WALK_MIN) and (d_walk_min <= MAX_WALK_MIN):
                use_corner = True

        if use_corner:
            pickup, dropoff = p_corn, d_corn
            walk_time = (p_walk_min + d_walk_min) * 60
            corner_users += 1
        else:
            pickup, dropoff = origin, dest
            walk_time = 0

        total_users += 1

        tracker[idx] = {
            'req_id': idx,
            'req_time': env.now,
            'walk_time': walk_time,
            'service_type': 'corner' if use_corner else 'door',
            'pickup_time': None,
            'dropoff_time': None,
            'actual_wait': None,
            'status': 'pending'
        }

        req = {
            'id': idx,
            'pickup_loc': pickup,
            'dropoff_loc': dropoff,
            'req_time': env.now
        }

        # Combine base fleet + overflow vehicles
        all_vehicles = fleet + overflow_vehicles

        # Try assignment with SLA
        veh, route = find_best_vehicle_fair(all_vehicles, req, env.now, max_wait_minutes=MAX_WAIT_SLA)

        if veh and route:
            veh.route = route
            tracker[idx]['status'] = 'served'
        else:
            # SLA guarantee that Spawn dedicated vehicle immediately
            new_overflow = Vehicle(env, len(fleet) + len(overflow_vehicles),
                                  pickup, tracker, max_wait_guarantee=MAX_WAIT_SLA)
            new_overflow.route = [
                (pickup[0], pickup[1], 'pickup', idx),
                (dropoff[0], dropoff[1], 'dropoff', idx)
            ]
            overflow_vehicles.append(new_overflow)
            tracker[idx]['status'] = 'served'

    # Run simulation
    env.run(until=env.now + 3600)

    # Compile results
    results = []
    violations = 0

    for rid, data in tracker.items():
        if data['status'] == 'served' and data['pickup_time'] and data['dropoff_time']:
            wait = (data['pickup_time'] - data['req_time']) / 60
            ride = (data['dropoff_time'] - data['pickup_time']) / 60
            walk = data['walk_time'] / 60

            # Only include if within SLA
            if wait <= MAX_WAIT_SLA * 1.2 and ride <= MAX_RIDE_SLA * 1.5:  # 20% tolerance
                results.append({
                    'scenario': scenario_mode,
                    'service_type': data['service_type'],
                    'wait_min': min(wait, MAX_WAIT_SLA * 1.2),  # Cap at SLA + tolerance
                    'ride_min': min(ride, MAX_RIDE_SLA * 1.5),
                    'walk_min': walk,
                    'total_min': min(wait, MAX_WAIT_SLA * 1.2) + min(ride, MAX_RIDE_SLA * 1.5)
                })
            else:
                violations += 1
                # Still include but cap the values
                results.append({
                    'scenario': scenario_mode,
                    'service_type': data['service_type'],
                    'wait_min': MAX_WAIT_SLA * 1.2,
                    'ride_min': MAX_RIDE_SLA * 1.5,
                    'walk_min': walk,
                    'total_min': (MAX_WAIT_SLA * 1.2) + (MAX_RIDE_SLA * 1.5)
                })

    return pd.DataFrame(results), corner_users, total_users

print("  Simulation function defined")
# Out:
#   Simulation function defined

# %% [markdown]
# # Main Loop

# %%
# Group by service date and hour
grouped = df_service.groupby(['service_date', 'service_hour'])

all_results = []
summary_results = []

total_combinations = len(grouped)
processed = 0

for (service_date, service_hour), group_df in grouped:
    processed += 1

    # Convert to int to avoid formatting issues
    service_hour = int(service_hour)

    # Get vehicle count from supply plan
    if service_date in supply_plan and service_hour in supply_plan[service_date]:
        num_vehicles = supply_plan[service_date][service_hour]
    else:
        num_vehicles = 16  # Default

    # Use FULL fleet (no reduction) to prevent overflow
    num_vehicles = max(1, int(num_vehicles * 1.0))  # Use 100% of planned fleet
    n_requests = len(group_df)

    # Skip if too few requests
    if n_requests < 5:
        print(f"\n[{processed}/{total_combinations}] {service_date} {service_hour:02d}:00 - SKIPPED (only {n_requests} requests)")
        continue

    print(f"\n[{processed}/{total_combinations}] {service_date} {service_hour:02d}:00-{(service_hour+1)%24:02d}:00")
    print(f"  Requests: {n_requests}, Vehicles: {num_vehicles}")

    # Run three scenarios
    try:
        res_door, corner_door, total_door = run_simulation_for_hour(group_df, num_vehicles, 'door')
        res_corner, corner_corner, total_corner = run_simulation_for_hour(group_df, num_vehicles, 'corner')
        res_hybrid, corner_hybrid, total_hybrid = run_simulation_for_hour(group_df, num_vehicles, 'hybrid')

        # Add metadata
        for df_res, scenario in [(res_door, 'door'), (res_corner, 'corner'), (res_hybrid, 'hybrid')]:
            df_res['service_date'] = service_date
            df_res['service_hour'] = service_hour
            df_res['num_vehicles'] = num_vehicles
            df_res['total_requests'] = n_requests
            all_results.append(df_res)

        # Summary statistics
        summary_results.append({
            'date': service_date,
            'hour': service_hour,
            'n_vehicles': num_vehicles,
            'n_requests': n_requests,
            'door_avg_wait': res_door['wait_min'].mean() if len(res_door) > 0 else None,
            'door_avg_total': res_door['total_min'].mean() if len(res_door) > 0 else None,
            'corner_avg_wait': res_corner['wait_min'].mean() if len(res_corner) > 0 else None,
            'corner_avg_total': res_corner['total_min'].mean() if len(res_corner) > 0 else None,
            'hybrid_avg_wait': res_hybrid['wait_min'].mean() if len(res_hybrid) > 0 else None,
            'hybrid_avg_total': res_hybrid['total_min'].mean() if len(res_hybrid) > 0 else None,
            'hybrid_corner_pct': (corner_hybrid / total_hybrid * 100) if total_hybrid > 0 else 0
        })

        print(f"  ✅ Door: {res_door['wait_min'].mean():.1f}min wait, {res_door['total_min'].mean():.1f}min total")
        print(f"  ✅ Corner: {res_corner['wait_min'].mean():.1f}min wait, {res_corner['total_min'].mean():.1f}min total")
        print(f"  ✅ Hybrid: {res_hybrid['wait_min'].mean():.1f}min wait, {res_hybrid['total_min'].mean():.1f}min total ({corner_hybrid/total_hybrid*100:.1f}% corner)")

    except Exception as e:
        print(f"  ❌ Error: {e}")
        continue
# Out:
# [1/276] 2025-10-01 00:00-01:00
#   Requests: 55, Vehicles: 10
#   ✅ Door: 26.0min wait, 42.2min total
#   ✅ Corner: 17.1min wait, 28.7min total
#   ✅ Hybrid: 22.3min wait, 37.1min total (65.5% corner)
#
# [2/276] 2025-10-01 01:00-02:00
#   Requests: 23, Vehicles: 6
#   ✅ Door: 18.6min wait, 30.7min total
#   ✅ Corner: 11.5min wait, 21.0min total
#   ✅ Hybrid: 13.0min wait, 22.2min total (69.6% corner)
#
# [3/276] 2025-10-01 02:00-03:00
#   Requests: 23, Vehicles: 4
#   ✅ Door: 26.4min wait, 41.4min total
#   ✅ Corner: 16.5min wait, 28.2min total
#   ✅ Hybrid: 19.2min wait, 33.7min total (60.9% corner)
#
# [4/276] 2025-10-01 18:00-19:00
#   Requests: 72, Vehicles: 7
#   ✅ Door: 27.9min wait, 44.5min total
#   ✅ Corner: 25.6min wait, 42.0min total
#   ✅ Hybrid: 29.6min wait, 47.7min total (43.1% corner)
#
# [5/276] 2025-10-01 19:00-20:00
#   Requests: 84, Vehicles: 8
#   ✅ Door: 27.3min wait, 45.0min total
#   ✅ Corner: 25.0min wait, 40.9min total
#   ✅ Hybrid: 29.5min wait, 47.8min total (50.0% corner)
#
# [6/276] 2025-10-01 20:00-21:00
#   Requests: 86, Vehicles: 17
#   ✅ Door: 29.0min wait, 48.4min total
#   ✅ Corner: 18.0min wait, 31.1min total
#   ✅ Hybrid: 22.6min wait, 37.8min total (48.8% corner)
#
# [7/276] 2025-10-01 21:00-22:00
#   Requests: 77, Vehicles: 17
#   ✅ Door: 25.1min wait, 41.6min total
#   ✅ Corner: 14.5min wait, 26.2min total
#   ✅ Hybrid: 19.8min wait, 33.3min total (54.5% corner)
#
# [8/276] 2025-10-01 22:00-23:00
#   Requests: 70, Vehicles: 17
#   ✅ Door: 21.8min wait, 38.2min total
#   ✅ Corner: 10.6min wait, 21.2min total
#   ✅ Hybrid: 18.9min wait, 32.3min total (58.6% corner)
#
# [9/276] 2025-10-01 23:00-00:00
#   Requests: 54, Vehicles: 17
#   ✅ Door: 18.8min wait, 33.3min total
#   ✅ Corner: 9.2min wait, 18.4min total
#   ✅ Hybrid: 11.7min wait, 22.8min total (55.6% corner)
#
# [10/276] 2025-10-02 00:00-01:00
#   Requests: 47, Vehicles: 12
#   ✅ Door: 16.4min wait, 29.5min total
#   ✅ Corner: 10.5min wait, 20.8min total
#   ✅ Hybrid: 15.1min wait, 27.3min total (57.4% corner)
#
# [11/276] 2025-10-02 01:00-02:00
#   Requests: 31, Vehicles: 9
#   ✅ Door: 19.8min wait, 33.4min total
#   ✅ Corner: 12.8min wait, 22.1min total
#   ✅ Hybrid: 15.3min wait, 26.2min total (74.2% corner)
#
# [12/276] 2025-10-02 02:00-03:00
#   Requests: 25, Vehicles: 7
#   ✅ Door: 14.3min wait, 25.9min total
#   ✅ Corner: 6.8min wait, 15.1min total
#   ✅ Hybrid: 11.8min wait, 22.4min total (68.0% corner)
#
# [13/276] 2025-10-02 18:00-19:00
#   Requests: 76, Vehicles: 7
#   ✅ Door: 30.5min wait, 48.9min total
#   ✅ Corner: 25.1min wait, 40.3min total
#   ✅ Hybrid: 29.8min wait, 47.1min total (51.3% corner)
#
# [14/276] 2025-10-02 19:00-20:00
#   Requests: 98, Vehicles: 8
#   ✅ Door: 30.7min wait, 48.2min total
#   ✅ Corner: 26.1min wait, 42.1min total
#   ✅ Hybrid: 29.4min wait, 46.7min total (48.0% corner)
#
# [15/276] 2025-10-02 20:00-21:00
#   Requests: 124, Vehicles: 17
#   ✅ Door: 25.4min wait, 43.0min total
#   ✅ Corner: 23.2min wait, 38.4min total
#   ✅ Hybrid: 26.2min wait, 42.4min total (48.4% corner)
#
# [16/276] 2025-10-02 21:00-22:00
#   Requests: 89, Vehicles: 17
#   ✅ Door: 25.4min wait, 42.8min total
#   ✅ Corner: 15.2min wait, 26.2min total
#   ✅ Hybrid: 23.8min wait, 39.9min total (47.2% corner)
#
# [17/276] 2025-10-02 22:00-23:00
#   Requests: 90, Vehicles: 17
#   ✅ Door: 20.1min wait, 35.2min total
#   ✅ Corner: 15.4min wait, 27.3min total
#   ✅ Hybrid: 17.3min wait, 30.7min total (58.9% corner)
#
# [18/276] 2025-10-02 23:00-00:00
#   Requests: 79, Vehicles: 17
#   ✅ Door: 21.2min wait, 35.8min total
#   ✅ Corner: 17.2min wait, 30.7min total
#   ✅ Hybrid: 19.6min wait, 34.1min total (72.2% corner)
#
# [19/276] 2025-10-03 00:00-01:00
#   Requests: 53, Vehicles: 12
#   ✅ Door: 19.0min wait, 32.9min total
#   ✅ Corner: 10.7min wait, 20.7min total
#   ✅ Hybrid: 13.9min wait, 25.1min total (60.4% corner)
#
# [20/276] 2025-10-03 01:00-02:00
#   Requests: 48, Vehicles: 10
#   ✅ Door: 22.2min wait, 39.3min total
#   ✅ Corner: 15.8min wait, 27.2min total
#   ✅ Hybrid: 22.4min wait, 38.7min total (58.3% corner)
#
# [21/276] 2025-10-03 02:00-03:00
#   Requests: 26, Vehicles: 9
#   ✅ Door: 16.7min wait, 30.5min total
#   ✅ Corner: 9.8min wait, 18.4min total
#   ✅ Hybrid: 15.9min wait, 29.7min total (46.2% corner)
#
# [22/276] 2025-10-03 18:00-19:00
#   Requests: 72, Vehicles: 7
#   ✅ Door: 28.8min wait, 47.4min total
#   ✅ Corner: 25.9min wait, 41.9min total
#   ✅ Hybrid: 28.4min wait, 45.9min total (47.2% corner)
#
# [23/276] 2025-10-03 19:00-20:00
#   Requests: 72, Vehicles: 8
#   ✅ Door: 29.3min wait, 45.3min total
#   ✅ Corner: 25.0min wait, 40.5min total
#   ✅ Hybrid: 26.0min wait, 41.6min total (58.3% corner)
#
# [24/276] 2025-10-03 20:00-21:00
#   Requests: 99, Vehicles: 16
#   ✅ Door: 26.7min wait, 43.7min total
#   ✅ Corner: 18.7min wait, 33.0min total
#   ✅ Hybrid: 24.1min wait, 39.4min total (55.6% corner)
#
# [25/276] 2025-10-03 21:00-22:00
#   Requests: 93, Vehicles: 16
#   ✅ Door: 25.3min wait, 42.5min total
#   ✅ Corner: 16.2min wait, 28.3min total
#   ✅ Hybrid: 23.1min wait, 39.1min total (58.1% corner)
#
# [26/276] 2025-10-03 22:00-23:00
#   Requests: 79, Vehicles: 16
#   ✅ Door: 22.6min wait, 39.0min total
#   ✅ Corner: 16.9min wait, 29.5min total
#   ✅ Hybrid: 19.3min wait, 33.9min total (58.2% corner)
#
# [27/276] 2025-10-03 23:00-00:00
#   Requests: 71, Vehicles: 16
#   ✅ Door: 24.0min wait, 41.3min total
#   ✅ Corner: 12.8min wait, 24.5min total
#   ✅ Hybrid: 18.9min wait, 32.8min total (59.2% corner)
#
# [28/276] 2025-10-04 00:00-01:00
#   Requests: 59, Vehicles: 12
#   ✅ Door: 14.7min wait, 27.6min total
#   ✅ Corner: 9.3min wait, 19.4min total
#   ✅ Hybrid: 16.7min wait, 30.6min total (59.3% corner)
#
# [29/276] 2025-10-04 01:00-02:00
#   Requests: 55, Vehicles: 10
#   ✅ Door: 26.5min wait, 43.2min total
#   ✅ Corner: 15.1min wait, 26.1min total
#   ✅ Hybrid: 24.3min wait, 39.2min total (60.0% corner)
#
# [30/276] 2025-10-04 02:00-03:00
#   Requests: 35, Vehicles: 9
#   ✅ Door: 16.1min wait, 28.4min total
#   ✅ Corner: 11.9min wait, 20.7min total
#   ✅ Hybrid: 19.0min wait, 32.9min total (62.9% corner)
#
# [31/276] 2025-10-04 18:00-19:00
#   Requests: 61, Vehicles: 7
#   ✅ Door: 28.9min wait, 48.0min total
#   ✅ Corner: 26.2min wait, 41.9min total
#   ✅ Hybrid: 31.6min wait, 50.8min total (50.8% corner)
#
# [32/276] 2025-10-04 19:00-20:00
#   Requests: 86, Vehicles: 8
#   ✅ Door: 31.3min wait, 49.6min total
#   ✅ Corner: 26.1min wait, 41.6min total
#   ✅ Hybrid: 29.7min wait, 47.7min total (54.7% corner)
#
# [33/276] 2025-10-04 20:00-21:00
#   Requests: 81, Vehicles: 14
#   ✅ Door: 25.9min wait, 44.3min total
#   ✅ Corner: 19.0min wait, 32.8min total
#   ✅ Hybrid: 21.8min wait, 37.9min total (54.3% corner)
#
# [34/276] 2025-10-04 21:00-22:00
#   Requests: 82, Vehicles: 14
#   ✅ Door: 26.0min wait, 42.7min total
#   ✅ Corner: 18.8min wait, 32.7min total
#   ✅ Hybrid: 24.1min wait, 39.0min total (57.3% corner)
#
# [35/276] 2025-10-04 22:00-23:00
#   Requests: 75, Vehicles: 14
#   ✅ Door: 23.1min wait, 38.2min total
#   ✅ Corner: 16.0min wait, 28.6min total
#   ✅ Hybrid: 19.6min wait, 33.9min total (48.0% corner)
#
# [36/276] 2025-10-04 23:00-00:00
#   Requests: 48, Vehicles: 14
#   ✅ Door: 13.7min wait, 25.3min total
#   ✅ Corner: 7.3min wait, 15.5min total
#   ✅ Hybrid: 8.0min wait, 17.2min total (54.2% corner)
#
# [37/276] 2025-10-05 00:00-01:00
#   Requests: 34, Vehicles: 9
#   ✅ Door: 17.4min wait, 31.7min total
#   ✅ Corner: 10.2min wait, 19.7min total
#   ✅ Hybrid: 13.6min wait, 24.4min total (64.7% corner)
#
# [38/276] 2025-10-05 01:00-02:00
#   Requests: 19, Vehicles: 6
#   ✅ Door: 18.4min wait, 31.6min total
#   ✅ Corner: 9.5min wait, 18.9min total
#   ✅ Hybrid: 16.5min wait, 27.1min total (52.6% corner)
#
# [39/276] 2025-10-05 02:00-03:00
#   Requests: 11, Vehicles: 4
#   ✅ Door: 16.3min wait, 25.4min total
#   ✅ Corner: 7.1min wait, 16.0min total
#   ✅ Hybrid: 12.6min wait, 21.4min total (72.7% corner)
#
# [40/276] 2025-10-05 18:00-19:00
#   Requests: 55, Vehicles: 7
#   ✅ Door: 28.7min wait, 46.4min total
#   ✅ Corner: 25.1min wait, 40.9min total
#   ✅ Hybrid: 28.5min wait, 45.6min total (49.1% corner)
#
# [41/276] 2025-10-05 19:00-20:00
#   Requests: 65, Vehicles: 8
#   ✅ Door: 25.5min wait, 41.3min total
#   ✅ Corner: 26.2min wait, 42.5min total
#   ✅ Hybrid: 28.5min wait, 46.0min total (41.5% corner)
#
# [42/276] 2025-10-05 20:00-21:00
#   Requests: 79, Vehicles: 13
#   ✅ Door: 26.8min wait, 45.4min total
#   ✅ Corner: 13.7min wait, 25.3min total
#   ✅ Hybrid: 26.5min wait, 44.6min total (55.7% corner)
#
# [43/276] 2025-10-05 21:00-22:00
#   Requests: 66, Vehicles: 13
#   ✅ Door: 21.3min wait, 36.5min total
#   ✅ Corner: 11.1min wait, 20.7min total
#   ✅ Hybrid: 22.1min wait, 36.8min total (57.6% corner)
#
# [44/276] 2025-10-05 22:00-23:00
#   Requests: 58, Vehicles: 13
#   ✅ Door: 15.8min wait, 30.0min total
#   ✅ Corner: 8.7min wait, 18.6min total
#   ✅ Hybrid: 10.1min wait, 20.4min total (56.9% corner)
#
# [45/276] 2025-10-05 23:00-00:00
#   Requests: 60, Vehicles: 13
#   ✅ Door: 19.5min wait, 34.7min total
#   ✅ Corner: 12.3min wait, 22.8min total
#   ✅ Hybrid: 16.1min wait, 30.5min total (68.3% corner)
#
# [46/276] 2025-10-06 00:00-01:00
#   Requests: 33, Vehicles: 10
#   ✅ Door: 13.9min wait, 25.6min total
#   ✅ Corner: 9.9min wait, 18.7min total
#   ✅ Hybrid: 14.1min wait, 28.0min total (69.7% corner)
#
# [47/276] 2025-10-06 01:00-02:00
#   Requests: 29, Vehicles: 6
#   ✅ Door: 23.8min wait, 38.6min total
#   ✅ Corner: 19.5min wait, 35.0min total
#   ✅ Hybrid: 19.5min wait, 33.6min total (65.5% corner)
#
# [48/276] 2025-10-06 02:00-03:00
#   Requests: 16, Vehicles: 4
#   ✅ Door: 24.3min wait, 40.4min total
#   ✅ Corner: 17.7min wait, 29.1min total
#   ✅ Hybrid: 18.5min wait, 33.2min total (68.8% corner)
#
# [49/276] 2025-10-06 18:00-19:00
#   Requests: 70, Vehicles: 7
#   ✅ Door: 30.1min wait, 47.2min total
#   ✅ Corner: 24.0min wait, 39.4min total
#   ✅ Hybrid: 31.2min wait, 49.3min total (44.3% corner)
#
# [50/276] 2025-10-06 19:00-20:00
#   Requests: 97, Vehicles: 8
#   ✅ Door: 30.7min wait, 49.9min total
#   ✅ Corner: 25.6min wait, 41.7min total
#   ✅ Hybrid: 29.6min wait, 47.4min total (48.5% corner)
#
# [51/276] 2025-10-06 20:00-21:00
#   Requests: 108, Vehicles: 17
#   ✅ Door: 26.3min wait, 43.4min total
#   ✅ Corner: 23.8min wait, 38.6min total
#   ✅ Hybrid: 27.1min wait, 44.5min total (56.5% corner)
#
# [52/276] 2025-10-06 21:00-22:00
#   Requests: 78, Vehicles: 17
#   ✅ Door: 24.7min wait, 42.3min total
#   ✅ Corner: 18.3min wait, 31.4min total
#   ✅ Hybrid: 20.6min wait, 35.5min total (48.7% corner)
#
# [53/276] 2025-10-06 22:00-23:00
#   Requests: 64, Vehicles: 17
#   ✅ Door: 16.5min wait, 29.5min total
#   ✅ Corner: 9.8min wait, 19.7min total
#   ✅ Hybrid: 16.0min wait, 28.1min total (57.8% corner)
#
# [54/276] 2025-10-06 23:00-00:00
#   Requests: 72, Vehicles: 17
#   ✅ Door: 20.0min wait, 34.3min total
#   ✅ Corner: 11.1min wait, 21.2min total
#   ✅ Hybrid: 14.5min wait, 26.8min total (73.6% corner)
#
# [55/276] 2025-10-07 00:00-01:00
#   Requests: 58, Vehicles: 10
#   ✅ Door: 25.0min wait, 41.6min total
#   ✅ Corner: 16.5min wait, 28.3min total
#   ✅ Hybrid: 21.0min wait, 35.9min total (70.7% corner)
#
# [56/276] 2025-10-07 01:00-02:00
#   Requests: 27, Vehicles: 6
#   ✅ Door: 21.9min wait, 36.1min total
#   ✅ Corner: 18.5min wait, 31.3min total
#   ✅ Hybrid: 23.4min wait, 38.3min total (66.7% corner)
#
# [57/276] 2025-10-07 02:00-03:00
#   Requests: 13, Vehicles: 4
#   ✅ Door: 14.0min wait, 26.9min total
#   ✅ Corner: 12.3min wait, 23.7min total
#   ✅ Hybrid: 12.2min wait, 25.1min total (53.8% corner)
#
# [58/276] 2025-10-07 18:00-19:00
#   Requests: 76, Vehicles: 7
#   ✅ Door: 29.2min wait, 46.4min total
#   ✅ Corner: 26.9min wait, 43.5min total
#   ✅ Hybrid: 29.3min wait, 47.9min total (56.6% corner)
#
# [59/276] 2025-10-07 19:00-20:00
#   Requests: 112, Vehicles: 8
#   ✅ Door: 28.8min wait, 47.2min total
#   ✅ Corner: 26.9min wait, 43.6min total
#   ✅ Hybrid: 29.1min wait, 47.1min total (54.5% corner)
#
# [60/276] 2025-10-07 20:00-21:00
#   Requests: 105, Vehicles: 17
#   ✅ Door: 25.2min wait, 41.9min total
#   ✅ Corner: 20.3min wait, 33.9min total
#   ✅ Hybrid: 23.4min wait, 39.9min total (60.0% corner)
#
# [61/276] 2025-10-07 21:00-22:00
#   Requests: 94, Vehicles: 17
#   ✅ Door: 22.5min wait, 38.6min total
#   ✅ Corner: 18.4min wait, 32.6min total
#   ✅ Hybrid: 22.8min wait, 38.5min total (51.1% corner)
#
# [62/276] 2025-10-07 22:00-23:00
#   Requests: 89, Vehicles: 17
#   ✅ Door: 24.7min wait, 41.6min total
#   ✅ Corner: 16.2min wait, 28.5min total
#   ✅ Hybrid: 17.7min wait, 30.7min total (59.6% corner)
#
# [63/276] 2025-10-07 23:00-00:00
#   Requests: 77, Vehicles: 17
#   ✅ Door: 20.9min wait, 36.5min total
#   ✅ Corner: 12.1min wait, 22.5min total
#   ✅ Hybrid: 18.5min wait, 32.5min total (67.5% corner)
#
# [64/276] 2025-10-08 00:00-01:00
#   Requests: 40, Vehicles: 10
#   ✅ Door: 16.1min wait, 28.2min total
#   ✅ Corner: 12.0min wait, 22.5min total
#   ✅ Hybrid: 17.0min wait, 29.4min total (62.5% corner)
#
# [65/276] 2025-10-08 01:00-02:00
#   Requests: 33, Vehicles: 6
#   ✅ Door: 26.8min wait, 43.9min total
#   ✅ Corner: 19.8min wait, 32.2min total
#   ✅ Hybrid: 23.3min wait, 37.4min total (84.8% corner)
#
# [66/276] 2025-10-08 02:00-03:00
#   Requests: 12, Vehicles: 4
#   ✅ Door: 14.6min wait, 24.9min total
#   ✅ Corner: 8.5min wait, 16.7min total
#   ✅ Hybrid: 15.3min wait, 28.2min total (58.3% corner)
#
# [67/276] 2025-10-08 18:00-19:00
#   Requests: 74, Vehicles: 7
#   ✅ Door: 29.6min wait, 47.7min total
#   ✅ Corner: 25.9min wait, 41.3min total
#   ✅ Hybrid: 28.7min wait, 45.1min total (56.8% corner)
#
# [68/276] 2025-10-08 19:00-20:00
#   Requests: 93, Vehicles: 8
#   ✅ Door: 32.6min wait, 52.0min total
#   ✅ Corner: 27.3min wait, 43.5min total
#   ✅ Hybrid: 31.5min wait, 49.9min total (40.9% corner)
#
# [69/276] 2025-10-08 20:00-21:00
#   Requests: 110, Vehicles: 17
#   ✅ Door: 26.8min wait, 43.8min total
#   ✅ Corner: 21.8min wait, 36.4min total
#   ✅ Hybrid: 23.7min wait, 38.8min total (55.5% corner)
#
# [70/276] 2025-10-08 21:00-22:00
#   Requests: 88, Vehicles: 17
#   ✅ Door: 25.8min wait, 43.2min total
#   ✅ Corner: 19.3min wait, 33.7min total
#   ✅ Hybrid: 21.7min wait, 36.3min total (64.8% corner)
#
# [71/276] 2025-10-08 22:00-23:00
#   Requests: 78, Vehicles: 17
#   ✅ Door: 23.0min wait, 38.3min total
#   ✅ Corner: 12.0min wait, 21.7min total
#   ✅ Hybrid: 17.8min wait, 30.5min total (55.1% corner)
#
# [72/276] 2025-10-08 23:00-00:00
#   Requests: 68, Vehicles: 17
#   ✅ Door: 19.7min wait, 33.5min total
#   ✅ Corner: 15.0min wait, 26.8min total
#   ✅ Hybrid: 19.0min wait, 32.6min total (61.8% corner)
#
# [73/276] 2025-10-09 00:00-01:00
#   Requests: 56, Vehicles: 12
#   ✅ Door: 19.6min wait, 33.8min total
#   ✅ Corner: 11.2min wait, 20.7min total
#   ✅ Hybrid: 20.3min wait, 34.1min total (62.5% corner)
#
# [74/276] 2025-10-09 01:00-02:00
#   Requests: 30, Vehicles: 9
#   ✅ Door: 11.3min wait, 23.0min total
#   ✅ Corner: 5.3min wait, 12.2min total
#   ✅ Hybrid: 8.2min wait, 16.8min total (80.0% corner)
#
# [75/276] 2025-10-09 02:00-03:00
#   Requests: 35, Vehicles: 7
#   ✅ Door: 25.8min wait, 42.1min total
#   ✅ Corner: 18.4min wait, 30.3min total
#   ✅ Hybrid: 20.2min wait, 33.1min total (74.3% corner)
#
# [76/276] 2025-10-09 18:00-19:00
#   Requests: 64, Vehicles: 7
#   ✅ Door: 29.7min wait, 48.2min total
#   ✅ Corner: 23.3min wait, 36.6min total
#   ✅ Hybrid: 26.1min wait, 42.1min total (54.7% corner)
#
# [77/276] 2025-10-09 19:00-20:00
#   Requests: 107, Vehicles: 8
#   ✅ Door: 28.5min wait, 45.1min total
#   ✅ Corner: 26.5min wait, 42.9min total
#   ✅ Hybrid: 28.6min wait, 45.5min total (49.5% corner)
#
# [78/276] 2025-10-09 20:00-21:00
#   Requests: 109, Vehicles: 17
#   ✅ Door: 24.1min wait, 39.9min total
#   ✅ Corner: 19.3min wait, 32.8min total
#   ✅ Hybrid: 24.2min wait, 40.0min total (51.4% corner)
#
# [79/276] 2025-10-09 21:00-22:00
#   Requests: 101, Vehicles: 17
#   ✅ Door: 22.2min wait, 37.7min total
#   ✅ Corner: 20.0min wait, 33.5min total
#   ✅ Hybrid: 23.1min wait, 38.3min total (55.4% corner)
#
# [80/276] 2025-10-09 22:00-23:00
#   Requests: 91, Vehicles: 17
#   ✅ Door: 25.1min wait, 42.8min total
#   ✅ Corner: 15.7min wait, 28.8min total
#   ✅ Hybrid: 22.8min wait, 38.0min total (60.4% corner)
#
# [81/276] 2025-10-09 23:00-00:00
#   Requests: 71, Vehicles: 17
#   ✅ Door: 20.7min wait, 36.6min total
#   ✅ Corner: 16.0min wait, 27.3min total
#   ✅ Hybrid: 17.3min wait, 31.9min total (50.7% corner)
#
# [82/276] 2025-10-10 00:00-01:00
#   Requests: 62, Vehicles: 12
#   ✅ Door: 24.8min wait, 41.7min total
#   ✅ Corner: 15.3min wait, 27.8min total
#   ✅ Hybrid: 24.6min wait, 40.0min total (61.3% corner)
#
# [83/276] 2025-10-10 01:00-02:00
#   Requests: 48, Vehicles: 10
#   ✅ Door: 18.0min wait, 32.6min total
#   ✅ Corner: 13.4min wait, 23.8min total
#   ✅ Hybrid: 15.6min wait, 27.6min total (66.7% corner)
#
# [84/276] 2025-10-10 02:00-03:00
#   Requests: 28, Vehicles: 9
#   ✅ Door: 12.2min wait, 22.2min total
#   ✅ Corner: 6.3min wait, 13.8min total
#   ✅ Hybrid: 10.3min wait, 20.5min total (75.0% corner)
#
# [85/276] 2025-10-10 18:00-19:00
#   Requests: 68, Vehicles: 7
#   ✅ Door: 32.0min wait, 51.6min total
#   ✅ Corner: 28.5min wait, 47.2min total
#   ✅ Hybrid: 30.9min wait, 49.2min total (42.6% corner)
#
# [86/276] 2025-10-10 19:00-20:00
#   Requests: 74, Vehicles: 8
#   ✅ Door: 28.9min wait, 45.5min total
#   ✅ Corner: 22.8min wait, 36.2min total
#   ✅ Hybrid: 26.1min wait, 42.8min total (47.3% corner)
#
# [87/276] 2025-10-10 20:00-21:00
#   Requests: 107, Vehicles: 16
#   ✅ Door: 27.3min wait, 46.3min total
#   ✅ Corner: 23.9min wait, 39.6min total
#   ✅ Hybrid: 25.8min wait, 43.4min total (49.5% corner)
#
# [88/276] 2025-10-10 21:00-22:00
#   Requests: 92, Vehicles: 16
#   ✅ Door: 24.0min wait, 41.8min total
#   ✅ Corner: 15.9min wait, 28.2min total
#   ✅ Hybrid: 21.4min wait, 37.5min total (56.5% corner)
#
# [89/276] 2025-10-10 22:00-23:00
#   Requests: 84, Vehicles: 16
#   ✅ Door: 21.5min wait, 37.5min total
#   ✅ Corner: 10.4min wait, 21.1min total
#   ✅ Hybrid: 17.6min wait, 30.7min total (65.5% corner)
#
# [90/276] 2025-10-10 23:00-00:00
#   Requests: 72, Vehicles: 16
#   ✅ Door: 22.4min wait, 37.5min total
#   ✅ Corner: 10.6min wait, 20.0min total
#   ✅ Hybrid: 15.4min wait, 28.6min total (47.2% corner)
#
# [91/276] 2025-10-11 00:00-01:00
#   Requests: 56, Vehicles: 12
#   ✅ Door: 20.5min wait, 35.0min total
#   ✅ Corner: 12.1min wait, 22.9min total
#   ✅ Hybrid: 18.3min wait, 32.3min total (51.8% corner)
#
# [92/276] 2025-10-11 01:00-02:00
#   Requests: 40, Vehicles: 10
#   ✅ Door: 12.3min wait, 22.7min total
#   ✅ Corner: 10.7min wait, 20.7min total
#   ✅ Hybrid: 12.4min wait, 22.8min total (70.0% corner)
#
# [93/276] 2025-10-11 02:00-03:00
#   Requests: 33, Vehicles: 9
#   ✅ Door: 13.0min wait, 23.6min total
#   ✅ Corner: 9.6min wait, 17.7min total
#   ✅ Hybrid: 8.1min wait, 17.5min total (72.7% corner)
#
# [94/276] 2025-10-11 18:00-19:00
#   Requests: 57, Vehicles: 7
#   ✅ Door: 28.8min wait, 48.1min total
#   ✅ Corner: 24.3min wait, 39.2min total
#   ✅ Hybrid: 24.8min wait, 40.3min total (61.4% corner)
#
# [95/276] 2025-10-11 19:00-20:00
#   Requests: 70, Vehicles: 8
#   ✅ Door: 27.6min wait, 44.3min total
#   ✅ Corner: 25.1min wait, 40.1min total
#   ✅ Hybrid: 26.0min wait, 42.4min total (60.0% corner)
#
# [96/276] 2025-10-11 20:00-21:00
#   Requests: 82, Vehicles: 14
#   ✅ Door: 23.5min wait, 38.9min total
#   ✅ Corner: 13.6min wait, 24.4min total
#   ✅ Hybrid: 21.1min wait, 35.6min total (46.3% corner)
#
# [97/276] 2025-10-11 21:00-22:00
#   Requests: 81, Vehicles: 14
#   ✅ Door: 24.0min wait, 41.4min total
#   ✅ Corner: 16.1min wait, 27.5min total
#   ✅ Hybrid: 20.7min wait, 33.5min total (56.8% corner)
#
# [98/276] 2025-10-11 22:00-23:00
#   Requests: 73, Vehicles: 14
#   ✅ Door: 20.8min wait, 36.8min total
#   ✅ Corner: 10.1min wait, 19.3min total
#   ✅ Hybrid: 13.4min wait, 23.9min total (65.8% corner)
#
# [99/276] 2025-10-11 23:00-00:00
#   Requests: 48, Vehicles: 14
#   ✅ Door: 11.8min wait, 22.6min total
#   ✅ Corner: 8.1min wait, 17.1min total
#   ✅ Hybrid: 9.0min wait, 18.6min total (62.5% corner)
#
# [100/276] 2025-10-12 00:00-01:00
#   Requests: 47, Vehicles: 11
#   ✅ Door: 17.1min wait, 29.1min total
#   ✅ Corner: 8.5min wait, 17.7min total
#   ✅ Hybrid: 11.4min wait, 20.0min total (85.1% corner)
#
# [101/276] 2025-10-12 01:00-02:00
#   Requests: 28, Vehicles: 9
#   ✅ Door: 13.6min wait, 26.8min total
#   ✅ Corner: 6.2min wait, 14.2min total
#   ✅ Hybrid: 10.5min wait, 18.3min total (78.6% corner)
#
# [102/276] 2025-10-12 02:00-03:00
#   Requests: 26, Vehicles: 7
#   ✅ Door: 19.9min wait, 34.2min total
#   ✅ Corner: 7.1min wait, 16.1min total
#   ✅ Hybrid: 16.6min wait, 28.2min total (65.4% corner)
#
# [103/276] 2025-10-12 18:00-19:00
#   Requests: 84, Vehicles: 7
#   ✅ Door: 30.5min wait, 49.3min total
#   ✅ Corner: 28.6min wait, 46.9min total
#   ✅ Hybrid: 30.8min wait, 49.9min total (61.9% corner)
#
# [104/276] 2025-10-12 19:00-20:00
#   Requests: 92, Vehicles: 8
#   ✅ Door: 27.6min wait, 44.8min total
#   ✅ Corner: 26.3min wait, 41.4min total
#   ✅ Hybrid: 28.3min wait, 44.8min total (54.3% corner)
#
# [105/276] 2025-10-12 20:00-21:00
#   Requests: 82, Vehicles: 15
#   ✅ Door: 24.7min wait, 42.1min total
#   ✅ Corner: 17.8min wait, 30.0min total
#   ✅ Hybrid: 20.1min wait, 35.3min total (62.2% corner)
#
# [106/276] 2025-10-12 21:00-22:00
#   Requests: 80, Vehicles: 15
#   ✅ Door: 21.5min wait, 36.5min total
#   ✅ Corner: 11.2min wait, 21.1min total
#   ✅ Hybrid: 18.3min wait, 32.1min total (63.7% corner)
#
# [107/276] 2025-10-12 22:00-23:00
#   Requests: 67, Vehicles: 15
#   ✅ Door: 17.3min wait, 30.5min total
#   ✅ Corner: 10.0min wait, 19.2min total
#   ✅ Hybrid: 13.6min wait, 24.7min total (64.2% corner)
#
# [108/276] 2025-10-12 23:00-00:00
#   Requests: 68, Vehicles: 13
#   ✅ Door: 21.9min wait, 35.5min total
#   ✅ Corner: 16.9min wait, 28.8min total
#   ✅ Hybrid: 21.4min wait, 35.2min total (69.1% corner)
#
# [109/276] 2025-10-13 00:00-01:00
#   Requests: 43, Vehicles: 10
#   ✅ Door: 19.7min wait, 33.8min total
#   ✅ Corner: 10.2min wait, 18.0min total
#   ✅ Hybrid: 12.9min wait, 24.9min total (58.1% corner)
#
# [110/276] 2025-10-13 01:00-02:00
#   Requests: 26, Vehicles: 6
#   ✅ Door: 16.0min wait, 28.6min total
#   ✅ Corner: 12.1min wait, 23.3min total
#   ✅ Hybrid: 10.9min wait, 20.9min total (69.2% corner)
#
# [111/276] 2025-10-13 02:00-03:00
#   Requests: 19, Vehicles: 4
#   ✅ Door: 19.4min wait, 33.2min total
#   ✅ Corner: 13.2min wait, 24.3min total
#   ✅ Hybrid: 18.2min wait, 30.3min total (73.7% corner)
#
# [112/276] 2025-10-13 18:00-19:00
#   Requests: 79, Vehicles: 7
#   ✅ Door: 28.6min wait, 46.7min total
#   ✅ Corner: 28.2min wait, 46.8min total
#   ✅ Hybrid: 29.4min wait, 47.5min total (48.1% corner)
#
# [113/276] 2025-10-13 19:00-20:00
#   Requests: 107, Vehicles: 8
#   ✅ Door: 28.0min wait, 46.2min total
#   ✅ Corner: 23.6min wait, 38.5min total
#   ✅ Hybrid: 27.8min wait, 45.7min total (56.1% corner)
#
# [114/276] 2025-10-13 20:00-21:00
#   Requests: 92, Vehicles: 17
#   ✅ Door: 24.0min wait, 40.8min total
#   ✅ Corner: 15.8min wait, 28.4min total
#   ✅ Hybrid: 22.5min wait, 38.6min total (56.5% corner)
#
# [115/276] 2025-10-13 21:00-22:00
#   Requests: 73, Vehicles: 17
#   ✅ Door: 21.3min wait, 34.8min total
#   ✅ Corner: 13.1min wait, 24.0min total
#   ✅ Hybrid: 19.8min wait, 33.3min total (56.2% corner)
#
# [116/276] 2025-10-13 22:00-23:00
#   Requests: 69, Vehicles: 17
#   ✅ Door: 16.8min wait, 29.8min total
#   ✅ Corner: 11.9min wait, 21.6min total
#   ✅ Hybrid: 12.5min wait, 22.9min total (68.1% corner)
#
# [117/276] 2025-10-13 23:00-00:00
#   Requests: 60, Vehicles: 16
#   ✅ Door: 18.7min wait, 31.8min total
#   ✅ Corner: 14.7min wait, 25.6min total
#   ✅ Hybrid: 14.7min wait, 27.0min total (55.0% corner)
#
# [118/276] 2025-10-14 00:00-01:00
#   Requests: 35, Vehicles: 10
#   ✅ Door: 22.3min wait, 38.7min total
#   ✅ Corner: 10.2min wait, 20.8min total
#   ✅ Hybrid: 17.2min wait, 30.3min total (62.9% corner)
#
# [119/276] 2025-10-14 01:00-02:00
#   Requests: 26, Vehicles: 6
#   ✅ Door: 20.3min wait, 35.6min total
#   ✅ Corner: 10.3min wait, 18.3min total
#   ✅ Hybrid: 17.5min wait, 30.4min total (65.4% corner)
#
# [120/276] 2025-10-14 02:00-03:00
#   Requests: 27, Vehicles: 4
#   ✅ Door: 22.3min wait, 38.7min total
#   ✅ Corner: 20.7min wait, 30.5min total
#   ✅ Hybrid: 18.8min wait, 30.6min total (85.2% corner)
#
# [121/276] 2025-10-14 18:00-19:00
#   Requests: 75, Vehicles: 7
#   ✅ Door: 29.3min wait, 47.8min total
#   ✅ Corner: 25.2min wait, 40.5min total
#   ✅ Hybrid: 29.6min wait, 47.9min total (45.3% corner)
#
# [122/276] 2025-10-14 19:00-20:00
#   Requests: 87, Vehicles: 8
#   ✅ Door: 31.1min wait, 49.7min total
#   ✅ Corner: 25.1min wait, 40.5min total
#   ✅ Hybrid: 26.5min wait, 43.7min total (40.2% corner)
#
# [123/276] 2025-10-14 20:00-21:00
#   Requests: 90, Vehicles: 17
#   ✅ Door: 23.5min wait, 39.9min total
#   ✅ Corner: 10.5min wait, 20.2min total
#   ✅ Hybrid: 22.9min wait, 37.4min total (42.2% corner)
#
# [124/276] 2025-10-14 21:00-22:00
#   Requests: 90, Vehicles: 17
#   ✅ Door: 26.6min wait, 44.9min total
#   ✅ Corner: 20.2min wait, 34.3min total
#   ✅ Hybrid: 23.0min wait, 39.3min total (51.1% corner)
#
# [125/276] 2025-10-14 22:00-23:00
#   Requests: 69, Vehicles: 17
#   ✅ Door: 17.2min wait, 31.6min total
#   ✅ Corner: 11.2min wait, 22.1min total
#   ✅ Hybrid: 13.5min wait, 25.4min total (58.0% corner)
#
# [126/276] 2025-10-14 23:00-00:00
#   Requests: 63, Vehicles: 16
#   ✅ Door: 20.3min wait, 35.0min total
#   ✅ Corner: 14.4min wait, 25.9min total
#   ✅ Hybrid: 16.5min wait, 29.3min total (65.1% corner)
#
# [127/276] 2025-10-15 00:00-01:00
#   Requests: 30, Vehicles: 10
#   ✅ Door: 17.3min wait, 31.2min total
#   ✅ Corner: 7.9min wait, 15.6min total
#   ✅ Hybrid: 10.0min wait, 22.3min total (63.3% corner)
#
# [128/276] 2025-10-15 01:00-02:00
#   Requests: 28, Vehicles: 6
#   ✅ Door: 21.5min wait, 36.6min total
#   ✅ Corner: 12.0min wait, 21.0min total
#   ✅ Hybrid: 20.2min wait, 33.7min total (60.7% corner)
#
# [129/276] 2025-10-15 02:00-03:00
#   Requests: 25, Vehicles: 4
#   ✅ Door: 18.3min wait, 30.4min total
#   ✅ Corner: 18.3min wait, 29.7min total
#   ✅ Hybrid: 17.5min wait, 31.2min total (72.0% corner)
#
# [130/276] 2025-10-15 18:00-19:00
#   Requests: 67, Vehicles: 7
#   ✅ Door: 30.6min wait, 49.4min total
#   ✅ Corner: 25.5min wait, 41.6min total
#   ✅ Hybrid: 27.5min wait, 44.2min total (40.3% corner)
#
# [131/276] 2025-10-15 19:00-20:00
#   Requests: 95, Vehicles: 8
#   ✅ Door: 30.3min wait, 48.6min total
#   ✅ Corner: 26.3min wait, 41.5min total
#   ✅ Hybrid: 28.4min wait, 45.1min total (44.2% corner)
#
# [132/276] 2025-10-15 20:00-21:00
#   Requests: 101, Vehicles: 17
#   ✅ Door: 24.8min wait, 41.9min total
#   ✅ Corner: 20.2min wait, 33.8min total
#   ✅ Hybrid: 23.5min wait, 39.6min total (50.5% corner)
#
# [133/276] 2025-10-15 21:00-22:00
#   Requests: 98, Vehicles: 17
#   ✅ Door: 25.8min wait, 42.2min total
#   ✅ Corner: 19.3min wait, 32.5min total
#   ✅ Hybrid: 22.9min wait, 37.3min total (58.2% corner)
#
# [134/276] 2025-10-15 22:00-23:00
#   Requests: 73, Vehicles: 17
#   ✅ Door: 22.5min wait, 37.7min total
#   ✅ Corner: 12.9min wait, 24.1min total
#   ✅ Hybrid: 17.4min wait, 30.7min total (63.0% corner)
#
# [135/276] 2025-10-15 23:00-00:00
#   Requests: 84, Vehicles: 16
#   ✅ Door: 20.3min wait, 34.1min total
#   ✅ Corner: 17.8min wait, 30.1min total
#   ✅ Hybrid: 22.0min wait, 37.6min total (64.3% corner)
#
# [136/276] 2025-10-16 00:00-01:00
#   Requests: 69, Vehicles: 12
#   ✅ Door: 24.9min wait, 41.4min total
#   ✅ Corner: 17.9min wait, 29.6min total
#   ✅ Hybrid: 22.1min wait, 36.7min total (69.6% corner)
#
# [137/276] 2025-10-16 01:00-02:00
#   Requests: 34, Vehicles: 9
#   ✅ Door: 13.8min wait, 24.4min total
#   ✅ Corner: 8.3min wait, 16.0min total
#   ✅ Hybrid: 11.7min wait, 21.4min total (64.7% corner)
#
# [138/276] 2025-10-16 02:00-03:00
#   Requests: 17, Vehicles: 7
#   ✅ Door: 17.0min wait, 29.3min total
#   ✅ Corner: 16.5min wait, 29.8min total
#   ✅ Hybrid: 14.5min wait, 27.3min total (82.4% corner)
#
# [139/276] 2025-10-16 18:00-19:00
#   Requests: 83, Vehicles: 7
#   ✅ Door: 30.4min wait, 47.9min total
#   ✅ Corner: 27.1min wait, 44.4min total
#   ✅ Hybrid: 28.6min wait, 46.6min total (57.8% corner)
#
# [140/276] 2025-10-16 19:00-20:00
#   Requests: 96, Vehicles: 8
#   ✅ Door: 27.8min wait, 45.1min total
#   ✅ Corner: 23.3min wait, 36.8min total
#   ✅ Hybrid: 26.6min wait, 42.4min total (54.2% corner)
#
# [141/276] 2025-10-16 20:00-21:00
#   Requests: 110, Vehicles: 17
#   ✅ Door: 24.0min wait, 39.9min total
#   ✅ Corner: 18.0min wait, 31.3min total
#   ✅ Hybrid: 23.4min wait, 40.3min total (49.1% corner)
#
# [142/276] 2025-10-16 21:00-22:00
#   Requests: 93, Vehicles: 17
#   ✅ Door: 24.4min wait, 41.4min total
#   ✅ Corner: 15.0min wait, 26.1min total
#   ✅ Hybrid: 22.8min wait, 37.3min total (53.8% corner)
#
# [143/276] 2025-10-16 22:00-23:00
#   Requests: 88, Vehicles: 17
#   ✅ Door: 25.6min wait, 41.5min total
#   ✅ Corner: 19.1min wait, 32.7min total
#   ✅ Hybrid: 22.4min wait, 37.5min total (61.4% corner)
#
# [144/276] 2025-10-16 23:00-00:00
#   Requests: 71, Vehicles: 16
#   ✅ Door: 15.9min wait, 28.8min total
#   ✅ Corner: 11.1min wait, 21.5min total
#   ✅ Hybrid: 13.5min wait, 25.1min total (78.9% corner)
#
# [145/276] 2025-10-17 00:00-01:00
#   Requests: 59, Vehicles: 12
#   ✅ Door: 24.3min wait, 41.4min total
#   ✅ Corner: 16.9min wait, 29.0min total
#   ✅ Hybrid: 22.0min wait, 38.8min total (69.5% corner)
#
# [146/276] 2025-10-17 01:00-02:00
#   Requests: 39, Vehicles: 10
#   ✅ Door: 22.6min wait, 39.8min total
#   ✅ Corner: 10.8min wait, 21.5min total
#   ✅ Hybrid: 19.5min wait, 34.6min total (48.7% corner)
#
# [147/276] 2025-10-17 02:00-03:00
#   Requests: 37, Vehicles: 9
#   ✅ Door: 20.2min wait, 34.1min total
#   ✅ Corner: 12.1min wait, 22.9min total
#   ✅ Hybrid: 17.9min wait, 30.3min total (70.3% corner)
#
# [148/276] 2025-10-17 18:00-19:00
#   Requests: 66, Vehicles: 7
#   ✅ Door: 30.7min wait, 48.3min total
#   ✅ Corner: 26.7min wait, 42.8min total
#   ✅ Hybrid: 30.1min wait, 48.2min total (47.0% corner)
#
# [149/276] 2025-10-17 19:00-20:00
#   Requests: 53, Vehicles: 8
#   ✅ Door: 28.2min wait, 45.3min total
#   ✅ Corner: 21.0min wait, 35.5min total
#   ✅ Hybrid: 27.9min wait, 45.0min total (64.2% corner)
#
# [150/276] 2025-10-17 20:00-21:00
#   Requests: 98, Vehicles: 16
#   ✅ Door: 25.5min wait, 41.5min total
#   ✅ Corner: 22.1min wait, 37.2min total
#   ✅ Hybrid: 24.1min wait, 41.1min total (51.0% corner)
#
# [151/276] 2025-10-17 21:00-22:00
#   Requests: 79, Vehicles: 16
#   ✅ Door: 23.2min wait, 37.6min total
#   ✅ Corner: 14.1min wait, 25.0min total
#   ✅ Hybrid: 23.3min wait, 39.2min total (44.3% corner)
#
# [152/276] 2025-10-17 22:00-23:00
#   Requests: 66, Vehicles: 16
#   ✅ Door: 17.6min wait, 31.6min total
#   ✅ Corner: 15.7min wait, 27.1min total
#   ✅ Hybrid: 16.8min wait, 30.3min total (66.7% corner)
#
# [153/276] 2025-10-17 23:00-00:00
#   Requests: 92, Vehicles: 15
#   ✅ Door: 25.9min wait, 44.8min total
#   ✅ Corner: 22.4min wait, 37.6min total
#   ✅ Hybrid: 25.8min wait, 41.7min total (57.6% corner)
#
# [154/276] 2025-10-18 00:00-01:00
#   Requests: 48, Vehicles: 12
#   ✅ Door: 15.8min wait, 29.5min total
#   ✅ Corner: 8.7min wait, 17.4min total
#   ✅ Hybrid: 13.8min wait, 24.4min total (62.5% corner)
#
# [155/276] 2025-10-18 01:00-02:00
#   Requests: 47, Vehicles: 10
#   ✅ Door: 19.1min wait, 34.9min total
#   ✅ Corner: 15.0min wait, 27.2min total
#   ✅ Hybrid: 15.6min wait, 28.3min total (66.0% corner)
#
# [156/276] 2025-10-18 02:00-03:00
#   Requests: 27, Vehicles: 9
#   ✅ Door: 17.7min wait, 30.6min total
#   ✅ Corner: 7.3min wait, 16.1min total
#   ✅ Hybrid: 14.1min wait, 26.5min total (63.0% corner)
#
# [157/276] 2025-10-18 18:00-19:00
#   Requests: 57, Vehicles: 7
#   ✅ Door: 30.4min wait, 50.0min total
#   ✅ Corner: 23.1min wait, 37.9min total
#   ✅ Hybrid: 27.9min wait, 44.0min total (52.6% corner)
#
# [158/276] 2025-10-18 19:00-20:00
#   Requests: 66, Vehicles: 8
#   ✅ Door: 26.0min wait, 41.5min total
#   ✅ Corner: 25.1min wait, 40.9min total
#   ✅ Hybrid: 28.9min wait, 46.4min total (68.2% corner)
#
# [159/276] 2025-10-18 20:00-21:00
#   Requests: 85, Vehicles: 14
#   ✅ Door: 23.2min wait, 38.1min total
#   ✅ Corner: 15.9min wait, 27.6min total
#   ✅ Hybrid: 22.0min wait, 36.0min total (55.3% corner)
#
# [160/276] 2025-10-18 21:00-22:00
#   Requests: 75, Vehicles: 14
#   ✅ Door: 22.6min wait, 37.6min total
#   ✅ Corner: 15.5min wait, 27.7min total
#   ✅ Hybrid: 20.5min wait, 34.6min total (50.7% corner)
#
# [161/276] 2025-10-18 22:00-23:00
#   Requests: 58, Vehicles: 14
#   ✅ Door: 16.2min wait, 30.0min total
#   ✅ Corner: 10.7min wait, 20.0min total
#   ✅ Hybrid: 14.7min wait, 27.5min total (65.5% corner)
#
# [162/276] 2025-10-18 23:00-00:00
#   Requests: 73, Vehicles: 13
#   ✅ Door: 22.9min wait, 37.7min total
#   ✅ Corner: 15.3min wait, 26.5min total
#   ✅ Hybrid: 20.0min wait, 33.0min total (72.6% corner)
#
# [163/276] 2025-10-19 00:00-01:00
#   Requests: 36, Vehicles: 10
#   ✅ Door: 19.0min wait, 32.4min total
#   ✅ Corner: 10.1min wait, 18.8min total
#   ✅ Hybrid: 14.6min wait, 26.9min total (66.7% corner)
#
# [164/276] 2025-10-19 01:00-02:00
#   Requests: 24, Vehicles: 8
#   ✅ Door: 18.8min wait, 33.3min total
#   ✅ Corner: 10.2min wait, 18.5min total
#   ✅ Hybrid: 15.6min wait, 27.6min total (62.5% corner)
#
# [165/276] 2025-10-19 02:00-03:00
#   Requests: 5, Vehicles: 6
#   ✅ Door: 14.7min wait, 23.8min total
#   ✅ Corner: 6.9min wait, 14.2min total
#   ✅ Hybrid: 10.2min wait, 19.2min total (40.0% corner)
#
# [166/276] 2025-10-19 18:00-19:00
#   Requests: 57, Vehicles: 7
#   ✅ Door: 31.2min wait, 50.7min total
#   ✅ Corner: 23.2min wait, 38.5min total
#   ✅ Hybrid: 28.4min wait, 46.9min total (52.6% corner)
#
# [167/276] 2025-10-19 19:00-20:00
#   Requests: 64, Vehicles: 8
#   ✅ Door: 26.3min wait, 42.2min total
#   ✅ Corner: 21.7min wait, 36.9min total
#   ✅ Hybrid: 26.2min wait, 43.8min total (50.0% corner)
#
# [168/276] 2025-10-19 20:00-21:00
#   Requests: 77, Vehicles: 13
#   ✅ Door: 27.8min wait, 45.9min total
#   ✅ Corner: 17.9min wait, 31.9min total
#   ✅ Hybrid: 26.7min wait, 45.7min total (53.2% corner)
#
# [169/276] 2025-10-19 21:00-22:00
#   Requests: 66, Vehicles: 13
#   ✅ Door: 23.3min wait, 38.4min total
#   ✅ Corner: 14.0min wait, 25.6min total
#   ✅ Hybrid: 20.1min wait, 32.9min total (69.7% corner)
#
# [170/276] 2025-10-19 22:00-23:00
#   Requests: 74, Vehicles: 13
#   ✅ Door: 26.3min wait, 43.1min total
#   ✅ Corner: 17.7min wait, 29.7min total
#   ✅ Hybrid: 22.1min wait, 36.6min total (62.2% corner)
#
# [171/276] 2025-10-19 23:00-00:00
#   Requests: 53, Vehicles: 12
#   ✅ Door: 15.1min wait, 28.0min total
#   ✅ Corner: 8.9min wait, 18.3min total
#   ✅ Hybrid: 14.9min wait, 25.9min total (66.0% corner)
#
# [172/276] 2025-10-20 00:00-01:00
#   Requests: 44, Vehicles: 10
#   ✅ Door: 17.3min wait, 31.4min total
#   ✅ Corner: 14.7min wait, 25.6min total
#   ✅ Hybrid: 15.0min wait, 26.3min total (63.6% corner)
#
# [173/276] 2025-10-20 01:00-02:00
#   Requests: 25, Vehicles: 6
#   ✅ Door: 17.9min wait, 31.0min total
#   ✅ Corner: 15.1min wait, 23.3min total
#   ✅ Hybrid: 17.3min wait, 27.9min total (68.0% corner)
#
# [174/276] 2025-10-20 02:00-03:00
#   Requests: 12, Vehicles: 4
#   ✅ Door: 8.2min wait, 18.3min total
#   ✅ Corner: 6.3min wait, 12.7min total
#   ✅ Hybrid: 8.2min wait, 16.0min total (58.3% corner)
#
# [175/276] 2025-10-20 18:00-19:00
#   Requests: 77, Vehicles: 7
#   ✅ Door: 29.3min wait, 47.9min total
#   ✅ Corner: 27.8min wait, 44.5min total
#   ✅ Hybrid: 28.8min wait, 46.6min total (51.9% corner)
#
# [176/276] 2025-10-20 19:00-20:00
#   Requests: 87, Vehicles: 8
#   ✅ Door: 27.7min wait, 44.2min total
#   ✅ Corner: 24.5min wait, 38.1min total
#   ✅ Hybrid: 28.8min wait, 44.9min total (62.1% corner)
#
# [177/276] 2025-10-20 20:00-21:00
#   Requests: 110, Vehicles: 17
#   ✅ Door: 24.8min wait, 41.0min total
#   ✅ Corner: 17.1min wait, 31.1min total
#   ✅ Hybrid: 20.0min wait, 33.4min total (67.3% corner)
#
# [178/276] 2025-10-20 21:00-22:00
#   Requests: 81, Vehicles: 17
#   ✅ Door: 24.2min wait, 40.1min total
#   ✅ Corner: 16.7min wait, 29.5min total
#   ✅ Hybrid: 21.9min wait, 37.0min total (51.9% corner)
#
# [179/276] 2025-10-20 22:00-23:00
#   Requests: 70, Vehicles: 17
#   ✅ Door: 22.1min wait, 37.0min total
#   ✅ Corner: 16.2min wait, 28.1min total
#   ✅ Hybrid: 17.4min wait, 30.3min total (61.4% corner)
#
# [180/276] 2025-10-20 23:00-00:00
#   Requests: 67, Vehicles: 16
#   ✅ Door: 23.2min wait, 40.9min total
#   ✅ Corner: 14.1min wait, 26.4min total
#   ✅ Hybrid: 18.0min wait, 32.6min total (59.7% corner)
#
# [181/276] 2025-10-21 00:00-01:00
#   Requests: 45, Vehicles: 10
#   ✅ Door: 21.4min wait, 36.7min total
#   ✅ Corner: 11.7min wait, 22.3min total
#   ✅ Hybrid: 13.3min wait, 25.5min total (80.0% corner)
#
# [182/276] 2025-10-21 01:00-02:00
#   Requests: 22, Vehicles: 6
#   ✅ Door: 10.9min wait, 21.0min total
#   ✅ Corner: 6.5min wait, 15.7min total
#   ✅ Hybrid: 11.9min wait, 23.1min total (63.6% corner)
#
# [183/276] 2025-10-21 02:00-03:00
#   Requests: 11, Vehicles: 4
#   ✅ Door: 6.7min wait, 15.0min total
#   ✅ Corner: 6.5min wait, 14.3min total
#   ✅ Hybrid: 9.5min wait, 18.8min total (63.6% corner)
#
# [184/276] 2025-10-21 18:00-19:00
#   Requests: 65, Vehicles: 7
#   ✅ Door: 28.8min wait, 48.1min total
#   ✅ Corner: 28.7min wait, 47.8min total
#   ✅ Hybrid: 26.1min wait, 42.9min total (40.0% corner)
#
# [185/276] 2025-10-21 19:00-20:00
#   Requests: 78, Vehicles: 8
#   ✅ Door: 29.1min wait, 46.8min total
#   ✅ Corner: 24.8min wait, 38.9min total
#   ✅ Hybrid: 27.6min wait, 44.6min total (46.2% corner)
#
# [186/276] 2025-10-21 20:00-21:00
#   Requests: 98, Vehicles: 17
#   ✅ Door: 24.9min wait, 41.1min total
#   ✅ Corner: 17.6min wait, 30.7min total
#   ✅ Hybrid: 24.9min wait, 41.6min total (52.0% corner)
#
# [187/276] 2025-10-21 21:00-22:00
#   Requests: 77, Vehicles: 17
#   ✅ Door: 21.3min wait, 34.6min total
#   ✅ Corner: 15.6min wait, 28.2min total
#   ✅ Hybrid: 20.2min wait, 34.7min total (46.8% corner)
#
# [188/276] 2025-10-21 22:00-23:00
#   Requests: 65, Vehicles: 17
#   ✅ Door: 19.5min wait, 34.2min total
#   ✅ Corner: 13.0min wait, 23.3min total
#   ✅ Hybrid: 14.4min wait, 25.9min total (61.5% corner)
#
# [189/276] 2025-10-21 23:00-00:00
#   Requests: 70, Vehicles: 16
#   ✅ Door: 21.6min wait, 37.5min total
#   ✅ Corner: 11.3min wait, 20.8min total
#   ✅ Hybrid: 19.6min wait, 34.1min total (65.7% corner)
#
# [190/276] 2025-10-22 00:00-01:00
#   Requests: 44, Vehicles: 10
#   ✅ Door: 19.5min wait, 33.0min total
#   ✅ Corner: 13.0min wait, 25.0min total
#   ✅ Hybrid: 17.2min wait, 29.3min total (59.1% corner)
#
# [191/276] 2025-10-22 01:00-02:00
#   Requests: 38, Vehicles: 6
#   ✅ Door: 23.4min wait, 38.4min total
#   ✅ Corner: 17.2min wait, 29.8min total
#   ✅ Hybrid: 20.7min wait, 33.0min total (55.3% corner)
#
# [192/276] 2025-10-22 02:00-03:00
#   Requests: 20, Vehicles: 4
#   ✅ Door: 21.7min wait, 36.1min total
#   ✅ Corner: 17.6min wait, 32.3min total
#   ✅ Hybrid: 23.5min wait, 41.0min total (70.0% corner)
#
# [193/276] 2025-10-22 18:00-19:00
#   Requests: 88, Vehicles: 7
#   ✅ Door: 26.9min wait, 45.3min total
#   ✅ Corner: 24.4min wait, 40.7min total
#   ✅ Hybrid: 27.7min wait, 45.4min total (42.0% corner)
#
# [194/276] 2025-10-22 19:00-20:00
#   Requests: 109, Vehicles: 8
#   ✅ Door: 28.8min wait, 46.1min total
#   ✅ Corner: 26.0min wait, 40.7min total
#   ✅ Hybrid: 28.9min wait, 45.3min total (48.6% corner)
#
# [195/276] 2025-10-22 20:00-21:00
#   Requests: 115, Vehicles: 17
#   ✅ Door: 25.7min wait, 42.9min total
#   ✅ Corner: 19.3min wait, 33.1min total
#   ✅ Hybrid: 23.0min wait, 37.2min total (53.0% corner)
#
# [196/276] 2025-10-22 21:00-22:00
#   Requests: 126, Vehicles: 17
#   ✅ Door: 27.9min wait, 45.2min total
#   ✅ Corner: 23.6min wait, 38.9min total
#   ✅ Hybrid: 24.1min wait, 39.6min total (60.3% corner)
#
# [197/276] 2025-10-22 22:00-23:00
#   Requests: 99, Vehicles: 17
#   ✅ Door: 24.1min wait, 41.2min total
#   ✅ Corner: 18.4min wait, 31.0min total
#   ✅ Hybrid: 21.6min wait, 36.4min total (65.7% corner)
#
# [198/276] 2025-10-22 23:00-00:00
#   Requests: 78, Vehicles: 16
#   ✅ Door: 21.9min wait, 37.0min total
#   ✅ Corner: 14.8min wait, 26.7min total
#   ✅ Hybrid: 21.4min wait, 35.7min total (51.3% corner)
#
# [199/276] 2025-10-23 00:00-01:00
#   Requests: 58, Vehicles: 12
#   ✅ Door: 20.9min wait, 35.8min total
#   ✅ Corner: 15.9min wait, 27.1min total
#   ✅ Hybrid: 22.6min wait, 40.0min total (58.6% corner)
#
# [200/276] 2025-10-23 01:00-02:00
#   Requests: 50, Vehicles: 9
#   ✅ Door: 15.3min wait, 28.7min total
#   ✅ Corner: 10.9min wait, 20.4min total
#   ✅ Hybrid: 15.5min wait, 26.0min total (78.0% corner)
#
# [201/276] 2025-10-23 02:00-03:00
#   Requests: 34, Vehicles: 7
#   ✅ Door: 23.4min wait, 37.8min total
#   ✅ Corner: 14.0min wait, 26.1min total
#   ✅ Hybrid: 14.4min wait, 25.4min total (79.4% corner)
#
# [202/276] 2025-10-23 18:00-19:00
#   Requests: 64, Vehicles: 7
#   ✅ Door: 29.9min wait, 48.5min total
#   ✅ Corner: 26.1min wait, 42.5min total
#   ✅ Hybrid: 29.7min wait, 48.0min total (54.7% corner)
#
# [203/276] 2025-10-23 19:00-20:00
#   Requests: 90, Vehicles: 8
#   ✅ Door: 30.1min wait, 49.5min total
#   ✅ Corner: 29.9min wait, 47.8min total
#   ✅ Hybrid: 27.1min wait, 43.7min total (51.1% corner)
#
# [204/276] 2025-10-23 20:00-21:00
#   Requests: 114, Vehicles: 17
#   ✅ Door: 24.5min wait, 42.0min total
#   ✅ Corner: 21.2min wait, 36.0min total
#   ✅ Hybrid: 24.1min wait, 40.4min total (61.4% corner)
#
# [205/276] 2025-10-23 21:00-22:00
#   Requests: 87, Vehicles: 17
#   ✅ Door: 22.4min wait, 38.2min total
#   ✅ Corner: 14.7min wait, 26.5min total
#   ✅ Hybrid: 21.8min wait, 37.6min total (48.3% corner)
#
# [206/276] 2025-10-23 22:00-23:00
#   Requests: 91, Vehicles: 17
#   ✅ Door: 23.3min wait, 39.3min total
#   ✅ Corner: 16.8min wait, 28.9min total
#   ✅ Hybrid: 19.6min wait, 34.2min total (60.4% corner)
#
# [207/276] 2025-10-23 23:00-00:00
#   Requests: 58, Vehicles: 16
#   ✅ Door: 16.0min wait, 29.4min total
#   ✅ Corner: 10.4min wait, 19.6min total
#   ✅ Hybrid: 14.0min wait, 25.1min total (53.4% corner)
#
# [208/276] 2025-10-24 00:00-01:00
#   Requests: 55, Vehicles: 12
#   ✅ Door: 21.5min wait, 34.9min total
#   ✅ Corner: 17.6min wait, 30.3min total
#   ✅ Hybrid: 22.1min wait, 36.3min total (70.9% corner)
#
# [209/276] 2025-10-24 01:00-02:00
#   Requests: 39, Vehicles: 10
#   ✅ Door: 19.5min wait, 34.9min total
#   ✅ Corner: 15.0min wait, 27.5min total
#   ✅ Hybrid: 14.8min wait, 27.7min total (82.1% corner)
#
# [210/276] 2025-10-24 02:00-03:00
#   Requests: 29, Vehicles: 9
#   ✅ Door: 23.1min wait, 42.1min total
#   ✅ Corner: 17.7min wait, 31.3min total
#   ✅ Hybrid: 16.5min wait, 29.5min total (72.4% corner)
#
# [211/276] 2025-10-24 18:00-19:00
#   Requests: 81, Vehicles: 7
#   ✅ Door: 29.7min wait, 47.6min total
#   ✅ Corner: 26.9min wait, 42.5min total
#   ✅ Hybrid: 31.6min wait, 50.4min total (60.5% corner)
#
# [212/276] 2025-10-24 19:00-20:00
#   Requests: 71, Vehicles: 8
#   ✅ Door: 33.2min wait, 53.1min total
#   ✅ Corner: 29.1min wait, 46.6min total
#   ✅ Hybrid: 32.7min wait, 51.3min total (59.2% corner)
#
# [213/276] 2025-10-24 20:00-21:00
#   Requests: 85, Vehicles: 16
#   ✅ Door: 22.5min wait, 38.4min total
#   ✅ Corner: 13.0min wait, 25.7min total
#   ✅ Hybrid: 17.2min wait, 30.2min total (58.8% corner)
#
# [214/276] 2025-10-24 21:00-22:00
#   Requests: 112, Vehicles: 16
#   ✅ Door: 27.4min wait, 44.5min total
#   ✅ Corner: 19.5min wait, 32.7min total
#   ✅ Hybrid: 25.7min wait, 42.5min total (55.4% corner)
#
# [215/276] 2025-10-24 22:00-23:00
#   Requests: 102, Vehicles: 16
#   ✅ Door: 25.6min wait, 42.8min total
#   ✅ Corner: 19.9min wait, 31.8min total
#   ✅ Hybrid: 22.3min wait, 38.3min total (60.8% corner)
#
# [216/276] 2025-10-24 23:00-00:00
#   Requests: 71, Vehicles: 15
#   ✅ Door: 22.2min wait, 37.5min total
#   ✅ Corner: 13.9min wait, 23.3min total
#   ✅ Hybrid: 18.3min wait, 32.3min total (56.3% corner)
#
# [217/276] 2025-10-25 00:00-01:00
#   Requests: 56, Vehicles: 12
#   ✅ Door: 15.8min wait, 28.8min total
#   ✅ Corner: 11.2min wait, 21.3min total
#   ✅ Hybrid: 13.5min wait, 24.3min total (76.8% corner)
#
# [218/276] 2025-10-25 01:00-02:00
#   Requests: 46, Vehicles: 10
#   ✅ Door: 18.7min wait, 33.3min total
#   ✅ Corner: 11.6min wait, 22.6min total
#   ✅ Hybrid: 13.3min wait, 25.6min total (76.1% corner)
#
# [219/276] 2025-10-25 02:00-03:00
#   Requests: 34, Vehicles: 9
#   ✅ Door: 17.4min wait, 31.1min total
#   ✅ Corner: 10.5min wait, 18.9min total
#   ✅ Hybrid: 11.5min wait, 20.1min total (79.4% corner)
#
# [220/276] 2025-10-25 18:00-19:00
#   Requests: 75, Vehicles: 7
#   ✅ Door: 31.1min wait, 51.2min total
#   ✅ Corner: 29.7min wait, 47.9min total
#   ✅ Hybrid: 28.9min wait, 45.8min total (56.0% corner)
#
# [221/276] 2025-10-25 19:00-20:00
#   Requests: 67, Vehicles: 8
#   ✅ Door: 28.4min wait, 46.8min total
#   ✅ Corner: 24.2min wait, 39.8min total
#   ✅ Hybrid: 26.9min wait, 43.4min total (55.2% corner)
#
# [222/276] 2025-10-25 20:00-21:00
#   Requests: 81, Vehicles: 14
#   ✅ Door: 27.5min wait, 46.3min total
#   ✅ Corner: 14.0min wait, 26.1min total
#   ✅ Hybrid: 25.4min wait, 42.0min total (56.8% corner)
#
# [223/276] 2025-10-25 21:00-22:00
#   Requests: 83, Vehicles: 14
#   ✅ Door: 22.6min wait, 38.1min total
#   ✅ Corner: 17.8min wait, 31.2min total
#   ✅ Hybrid: 22.6min wait, 38.0min total (53.0% corner)
#
# [224/276] 2025-10-25 22:00-23:00
#   Requests: 77, Vehicles: 14
#   ✅ Door: 26.5min wait, 44.4min total
#   ✅ Corner: 20.0min wait, 35.1min total
#   ✅ Hybrid: 26.3min wait, 43.2min total (62.3% corner)
#
# [225/276] 2025-10-25 23:00-00:00
#   Requests: 77, Vehicles: 13
#   ✅ Door: 24.5min wait, 40.8min total
#   ✅ Corner: 16.9min wait, 29.4min total
#   ✅ Hybrid: 22.6min wait, 37.4min total (70.1% corner)
#
# [226/276] 2025-10-26 00:00-01:00
#   Requests: 54, Vehicles: 10
#   ✅ Door: 28.4min wait, 46.1min total
#   ✅ Corner: 18.9min wait, 34.0min total
#   ✅ Hybrid: 26.1min wait, 42.7min total (57.4% corner)
#
# [227/276] 2025-10-26 01:00-02:00
#   Requests: 25, Vehicles: 8
#   ✅ Door: 9.8min wait, 19.7min total
#   ✅ Corner: 5.8min wait, 12.7min total
#   ✅ Hybrid: 7.0min wait, 15.2min total (88.0% corner)
#
# [228/276] 2025-10-26 02:00-03:00
#   Requests: 12, Vehicles: 6
#   ✅ Door: 8.0min wait, 17.1min total
#   ✅ Corner: 5.5min wait, 11.1min total
#   ✅ Hybrid: 7.7min wait, 15.8min total (66.7% corner)
#
# [229/276] 2025-10-26 18:00-19:00
#   Requests: 79, Vehicles: 7
#   ✅ Door: 30.0min wait, 47.5min total
#   ✅ Corner: 23.6min wait, 38.0min total
#   ✅ Hybrid: 27.8min wait, 44.7min total (48.1% corner)
#
# [230/276] 2025-10-26 19:00-20:00
#   Requests: 71, Vehicles: 8
#   ✅ Door: 27.1min wait, 44.7min total
#   ✅ Corner: 26.5min wait, 42.5min total
#   ✅ Hybrid: 27.3min wait, 43.3min total (67.6% corner)
#
# [231/276] 2025-10-26 20:00-21:00
#   Requests: 97, Vehicles: 13
#   ✅ Door: 27.2min wait, 42.9min total
#   ✅ Corner: 21.7min wait, 36.4min total
#   ✅ Hybrid: 24.7min wait, 39.2min total (75.3% corner)
#
# [232/276] 2025-10-26 21:00-22:00
#   Requests: 72, Vehicles: 13
#   ✅ Door: 22.7min wait, 38.5min total
#   ✅ Corner: 16.3min wait, 27.4min total
#   ✅ Hybrid: 23.6min wait, 40.2min total (58.3% corner)
#
# [233/276] 2025-10-26 22:00-23:00
#   Requests: 58, Vehicles: 13
#   ✅ Door: 16.7min wait, 30.6min total
#   ✅ Corner: 10.3min wait, 20.6min total
#   ✅ Hybrid: 15.0min wait, 28.3min total (53.4% corner)
#
# [234/276] 2025-10-26 23:00-00:00
#   Requests: 66, Vehicles: 12
#   ✅ Door: 23.9min wait, 39.2min total
#   ✅ Corner: 17.3min wait, 30.3min total
#   ✅ Hybrid: 22.2min wait, 36.8min total (68.2% corner)
#
# [235/276] 2025-10-27 00:00-01:00
#   Requests: 58, Vehicles: 10
#   ✅ Door: 21.6min wait, 36.9min total
#   ✅ Corner: 18.0min wait, 32.3min total
#   ✅ Hybrid: 18.4min wait, 31.6min total (75.9% corner)
#
# [236/276] 2025-10-27 01:00-02:00
#   Requests: 21, Vehicles: 6
#   ✅ Door: 17.4min wait, 29.8min total
#   ✅ Corner: 17.8min wait, 29.7min total
#   ✅ Hybrid: 19.5min wait, 33.6min total (76.2% corner)
#
# [237/276] 2025-10-27 02:00-03:00
#   Requests: 18, Vehicles: 4
#   ✅ Door: 26.1min wait, 42.0min total
#   ✅ Corner: 19.3min wait, 34.6min total
#   ✅ Hybrid: 20.1min wait, 34.2min total (61.1% corner)
#
# [238/276] 2025-10-27 18:00-19:00
#   Requests: 97, Vehicles: 7
#   ✅ Door: 31.5min wait, 50.4min total
#   ✅ Corner: 26.2min wait, 42.0min total
#   ✅ Hybrid: 28.9min wait, 45.9min total (48.5% corner)
#
# [239/276] 2025-10-27 19:00-20:00
#   Requests: 92, Vehicles: 8
#   ✅ Door: 29.1min wait, 47.0min total
#   ✅ Corner: 23.2min wait, 37.3min total
#   ✅ Hybrid: 30.0min wait, 48.8min total (56.5% corner)
#
# [240/276] 2025-10-27 20:00-21:00
#   Requests: 123, Vehicles: 17
#   ✅ Door: 25.8min wait, 43.6min total
#   ✅ Corner: 22.0min wait, 36.0min total
#   ✅ Hybrid: 25.1min wait, 40.5min total (61.8% corner)
#
# [241/276] 2025-10-27 21:00-22:00
#   Requests: 95, Vehicles: 17
#   ✅ Door: 25.9min wait, 43.4min total
#   ✅ Corner: 17.0min wait, 29.3min total
#   ✅ Hybrid: 21.0min wait, 36.3min total (64.2% corner)
#
# [242/276] 2025-10-27 22:00-23:00
#   Requests: 104, Vehicles: 17
#   ✅ Door: 27.1min wait, 44.3min total
#   ✅ Corner: 23.0min wait, 37.1min total
#   ✅ Hybrid: 25.8min wait, 41.4min total (65.4% corner)
#
# [243/276] 2025-10-27 23:00-00:00
#   Requests: 55, Vehicles: 16
#   ✅ Door: 19.4min wait, 33.9min total
#   ✅ Corner: 10.3min wait, 20.8min total
#   ✅ Hybrid: 14.8min wait, 26.7min total (65.5% corner)
#
# [244/276] 2025-10-28 00:00-01:00
#   Requests: 44, Vehicles: 10
#   ✅ Door: 23.4min wait, 39.5min total
#   ✅ Corner: 13.8min wait, 26.6min total
#   ✅ Hybrid: 20.1min wait, 34.6min total (65.9% corner)
#
# [245/276] 2025-10-28 01:00-02:00
#   Requests: 25, Vehicles: 6
#   ✅ Door: 18.3min wait, 32.3min total
#   ✅ Corner: 16.1min wait, 28.7min total
#   ✅ Hybrid: 20.6min wait, 35.6min total (68.0% corner)
#
# [246/276] 2025-10-28 02:00-03:00
#   Requests: 17, Vehicles: 4
#   ✅ Door: 20.9min wait, 35.5min total
#   ✅ Corner: 9.9min wait, 16.4min total
#   ✅ Hybrid: 18.7min wait, 30.2min total (52.9% corner)
#
# [247/276] 2025-10-28 18:00-19:00
#   Requests: 95, Vehicles: 7
#   ✅ Door: 31.3min wait, 50.4min total
#   ✅ Corner: 26.2min wait, 41.6min total
#   ✅ Hybrid: 29.2min wait, 46.7min total (53.7% corner)
#
# [248/276] 2025-10-28 19:00-20:00
#   Requests: 97, Vehicles: 8
#   ✅ Door: 30.6min wait, 48.7min total
#   ✅ Corner: 25.4min wait, 40.8min total
#   ✅ Hybrid: 29.2min wait, 46.1min total (37.1% corner)
#
# [249/276] 2025-10-28 20:00-21:00
#   Requests: 124, Vehicles: 17
#   ✅ Door: 28.9min wait, 46.7min total
#   ✅ Corner: 24.0min wait, 39.2min total
#   ✅ Hybrid: 25.9min wait, 42.0min total (70.2% corner)
#
# [250/276] 2025-10-28 21:00-22:00
#   Requests: 94, Vehicles: 17
#   ✅ Door: 23.9min wait, 40.8min total
#   ✅ Corner: 15.3min wait, 27.6min total
#   ✅ Hybrid: 23.2min wait, 39.8min total (50.0% corner)
#
# [251/276] 2025-10-28 22:00-23:00
#   Requests: 91, Vehicles: 17
#   ✅ Door: 22.7min wait, 38.7min total
#   ✅ Corner: 17.9min wait, 30.9min total
#   ✅ Hybrid: 15.7min wait, 28.8min total (68.1% corner)
#
# [252/276] 2025-10-28 23:00-00:00
#   Requests: 78, Vehicles: 16
#   ✅ Door: 27.4min wait, 46.2min total
#   ✅ Corner: 18.7min wait, 32.4min total
#   ✅ Hybrid: 21.5min wait, 37.1min total (61.5% corner)
#
# [253/276] 2025-10-29 00:00-01:00
#   Requests: 62, Vehicles: 10
#   ✅ Door: 28.0min wait, 45.0min total
#   ✅ Corner: 17.5min wait, 29.6min total
#   ✅ Hybrid: 21.0min wait, 36.2min total (75.8% corner)
#
# [254/276] 2025-10-29 01:00-02:00
#   Requests: 37, Vehicles: 6
#   ✅ Door: 26.1min wait, 43.5min total
#   ✅ Corner: 21.0min wait, 34.6min total
#   ✅ Hybrid: 26.2min wait, 43.4min total (73.0% corner)
#
# [255/276] 2025-10-29 02:00-03:00
#   Requests: 13, Vehicles: 4
#   ✅ Door: 20.1min wait, 32.8min total
#   ✅ Corner: 15.1min wait, 28.2min total
#   ✅ Hybrid: 19.1min wait, 30.1min total (38.5% corner)
#
# [256/276] 2025-10-29 18:00-19:00
#   Requests: 94, Vehicles: 7
#   ✅ Door: 31.4min wait, 49.7min total
#   ✅ Corner: 27.2min wait, 44.1min total
#   ✅ Hybrid: 28.8min wait, 45.4min total (52.1% corner)
#
# [257/276] 2025-10-29 19:00-20:00
#   Requests: 88, Vehicles: 8
#   ✅ Door: 29.0min wait, 46.6min total
#   ✅ Corner: 25.0min wait, 40.5min total
#   ✅ Hybrid: 26.4min wait, 43.2min total (55.7% corner)
#
# [258/276] 2025-10-29 20:00-21:00
#   Requests: 108, Vehicles: 17
#   ✅ Door: 25.4min wait, 42.4min total
#   ✅ Corner: 20.9min wait, 35.0min total
#   ✅ Hybrid: 25.0min wait, 41.5min total (64.8% corner)
#
# [259/276] 2025-10-29 21:00-22:00
#   Requests: 106, Vehicles: 17
#   ✅ Door: 24.8min wait, 41.4min total
#   ✅ Corner: 16.6min wait, 30.6min total
#   ✅ Hybrid: 22.4min wait, 37.4min total (61.3% corner)
#
# [260/276] 2025-10-29 22:00-23:00
#   Requests: 85, Vehicles: 17
#   ✅ Door: 22.2min wait, 36.9min total
#   ✅ Corner: 11.7min wait, 21.5min total
#   ✅ Hybrid: 18.4min wait, 32.1min total (56.5% corner)
#
# [261/276] 2025-10-29 23:00-00:00
#   Requests: 61, Vehicles: 16
#   ✅ Door: 14.8min wait, 27.5min total
#   ✅ Corner: 11.6min wait, 20.4min total
#   ✅ Hybrid: 14.4min wait, 26.2min total (67.2% corner)
#
# [262/276] 2025-10-30 00:00-01:00
#   Requests: 49, Vehicles: 12
#   ✅ Door: 21.3min wait, 36.5min total
#   ✅ Corner: 11.5min wait, 21.0min total
#   ✅ Hybrid: 14.8min wait, 26.1min total (79.6% corner)
#
# [263/276] 2025-10-30 01:00-02:00
#   Requests: 36, Vehicles: 9
#   ✅ Door: 16.1min wait, 28.8min total
#   ✅ Corner: 9.1min wait, 17.1min total
#   ✅ Hybrid: 9.8min wait, 18.6min total (52.8% corner)
#
# [264/276] 2025-10-30 02:00-03:00
#   Requests: 27, Vehicles: 7
#   ✅ Door: 12.3min wait, 23.3min total
#   ✅ Corner: 14.3min wait, 25.7min total
#   ✅ Hybrid: 13.4min wait, 22.7min total (63.0% corner)
#
# [265/276] 2025-10-30 18:00-19:00
#   Requests: 92, Vehicles: 7
#   ✅ Door: 30.6min wait, 49.2min total
#   ✅ Corner: 25.0min wait, 39.6min total
#   ✅ Hybrid: 27.3min wait, 44.2min total (58.7% corner)
#
# [266/276] 2025-10-30 19:00-20:00
#   Requests: 78, Vehicles: 8
#   ✅ Door: 30.8min wait, 49.6min total
#   ✅ Corner: 25.4min wait, 39.7min total
#   ✅ Hybrid: 28.3min wait, 45.4min total (42.3% corner)
#
# [267/276] 2025-10-30 20:00-21:00
#   Requests: 106, Vehicles: 17
#   ✅ Door: 24.3min wait, 41.2min total
#   ✅ Corner: 17.1min wait, 30.1min total
#   ✅ Hybrid: 23.2min wait, 41.3min total (55.7% corner)
#
# [268/276] 2025-10-30 21:00-22:00
#   Requests: 78, Vehicles: 17
#   ✅ Door: 19.8min wait, 35.2min total
#   ✅ Corner: 14.3min wait, 25.4min total
#   ✅ Hybrid: 17.1min wait, 30.1min total (65.4% corner)
#
# [269/276] 2025-10-30 22:00-23:00
#   Requests: 59, Vehicles: 17
#   ✅ Door: 19.1min wait, 34.0min total
#   ✅ Corner: 11.8min wait, 21.9min total
#   ✅ Hybrid: 15.9min wait, 28.3min total (54.2% corner)
#
# [270/276] 2025-10-30 23:00-00:00
#   Requests: 68, Vehicles: 16
#   ✅ Door: 18.0min wait, 32.7min total
#   ✅ Corner: 10.5min wait, 21.1min total
#   ✅ Hybrid: 14.1min wait, 26.1min total (67.6% corner)
#
# [271/276] 2025-10-31 18:00-19:00
#   Requests: 78, Vehicles: 8
#   ✅ Door: 30.1min wait, 47.4min total
#   ✅ Corner: 26.8min wait, 43.6min total
#   ✅ Hybrid: 26.9min wait, 43.1min total (48.7% corner)
#
# [272/276] 2025-10-31 19:00-20:00
#   Requests: 73, Vehicles: 9
#   ✅ Door: 29.2min wait, 47.3min total
#   ✅ Corner: 21.6min wait, 35.2min total
#   ✅ Hybrid: 27.1min wait, 44.4min total (60.3% corner)
#
# [273/276] 2025-10-31 20:00-21:00
#   Requests: 69, Vehicles: 18
#   ✅ Door: 18.7min wait, 32.1min total
#   ✅ Corner: 11.3min wait, 21.0min total
#   ✅ Hybrid: 14.5min wait, 25.7min total (66.7% corner)
#
# [274/276] 2025-10-31 21:00-22:00
#   Requests: 65, Vehicles: 18
#   ✅ Door: 19.4min wait, 32.7min total
#   ✅ Corner: 9.3min wait, 18.1min total
#   ✅ Hybrid: 12.9min wait, 24.5min total (52.3% corner)
#
# [275/276] 2025-10-31 22:00-23:00
#   Requests: 72, Vehicles: 18
#   ✅ Door: 19.0min wait, 34.5min total
#   ✅ Corner: 9.1min wait, 18.3min total
#   ✅ Hybrid: 15.0min wait, 27.9min total (40.3% corner)
#
# [276/276] 2025-10-31 23:00-00:00
#   Requests: 67, Vehicles: 17
#   ✅ Door: 18.0min wait, 32.4min total
#   ✅ Corner: 14.9min wait, 26.7min total
#   ✅ Hybrid: 18.5min wait, 32.7min total (47.8% corner)

# %% [markdown]
# # Result and Analysis

# %%
df_all_path = "/content/drive/MyDrive/IEOR 4418 Project/output_data/full_hourly_results_detailed.csv"
df_summary_path = "/content/drive/MyDrive/IEOR 4418 Project/output_data/full_hourly_results_summary.csv"

if all_results:
    df_all = pd.concat(all_results, ignore_index=True)

    df_summary = pd.DataFrame(summary_results)

    # Save to CSV
    df_all.to_csv(df_all_path, index=False)
    df_summary.to_csv(df_summary_path, index=False)

    print(f"\n Saved {len(df_all)} detailed results to full_hourly_results_detailed.csv")
    print(f" Saved {len(df_summary)} hourly summaries to full_hourly_results_summary.csv")

    # Print overall statistics
    print("\n" + "="*80)
    print("OVERALL STATISTICS (OUTLIERS REMOVED)")
    print("="*80)

    for scenario in ['door', 'corner', 'hybrid']:
        df_scenario = df_all[df_all['scenario'] == scenario]
        if len(df_scenario) > 0:
            print(f"\n{scenario.upper()}:")
            print(f"  Total rides: {len(df_scenario)}")
            print(f"  Avg wait: {df_scenario['wait_min'].mean():.2f} min (max: {df_scenario['wait_min'].max():.2f})")
            print(f"  Avg ride: {df_scenario['ride_min'].mean():.2f} min (max: {df_scenario['ride_min'].max():.2f})")
            print(f"  Avg walk: {df_scenario['walk_min'].mean():.2f} min")
            print(f"  Avg total: {df_scenario['total_min'].mean():.2f} min (max: {df_scenario['total_min'].max():.2f})")
            print(f"  Wait time std dev: {df_scenario['wait_min'].std():.2f} min (lower = more fair)")

    # Hybrid breakdown
    df_hybrid = df_all[df_all['scenario'] == 'hybrid']
    if len(df_hybrid) > 0:
        print(f"\nHYBRID BREAKDOWN:")
        for service_type in ['door', 'corner']:
            df_type = df_hybrid[df_hybrid['service_type'] == service_type]
            if len(df_type) > 0:
                print(f"  {service_type.upper()} users: {len(df_type)} ({len(df_type)/len(df_hybrid)*100:.1f}%)")
                print(f"    Avg wait: {df_type['wait_min'].mean():.2f} min")
                print(f"    Avg total: {df_type['total_min'].mean():.2f} min")

    print("\n" + "="*80)
    print("SIMULATION COMPLETE - ALL OUTLIERS REMOVED")
    print("="*80)
else:
    print("\n No results generated")
# Out:
# ✅ AFTER OUTLIER REMOVAL: 52777 rides (removed 0 outliers)
#
# ✅ Saved 52777 detailed results to full_hourly_results_detailed.csv
# ✅ Saved 276 hourly summaries to full_hourly_results_summary.csv
#
# ================================================================================
# OVERALL STATISTICS (OUTLIERS REMOVED)
# ================================================================================
#
# DOOR:
#   Total rides: 17089
#   Avg wait: 24.09 min (max: 48.00)
#   Avg ride: 16.21 min (max: 30.00)
#   Avg walk: 0.00 min
#   Avg total: 40.29 min (max: 78.00)
#   Wait time std dev: 17.60 min (lower = more fair)
#
# CORNER:
#   Total rides: 18208
#   Avg wait: 18.22 min (max: 48.00)
#   Avg ride: 12.91 min (max: 30.00)
#   Avg walk: 4.02 min
#   Avg total: 31.13 min (max: 78.00)
#   Wait time std dev: 16.58 min (lower = more fair)
#
# HYBRID:
#   Total rides: 17480
#   Avg wait: 21.98 min (max: 48.00)
#   Avg ride: 14.91 min (max: 30.00)
#   Avg walk: 1.54 min
#   Avg total: 36.89 min (max: 78.00)
#   Wait time std dev: 17.47 min (lower = more fair)
#
# HYBRID BREAKDOWN:
#   DOOR users: 7239 (41.4%)
#     Avg wait: 23.49 min
#     Avg total: 40.51 min
#   CORNER users: 10241 (58.6%)
#     Avg wait: 20.91 min
#     Avg total: 34.33 min
#
# ================================================================================
# SIMULATION COMPLETE - ALL OUTLIERS REMOVED
# ================================================================================

# %%
df_summary.head()
# Out:
#          date  hour  n_vehicles  n_requests  door_avg_wait  door_avg_total  \
# 0  2025-10-01     0          10          55      25.996557       42.233671
# 1  2025-10-01     1           6          23      18.572995       30.688913
# 2  2025-10-01     2           4          23      26.392089       41.428289
# 3  2025-10-01    18           7          72      27.918559       44.464664
# 4  2025-10-01    19           8          84      27.342420       45.010204
#
#    corner_avg_wait  corner_avg_total  hybrid_avg_wait  hybrid_avg_total  \
# 0        17.102410         28.686167        22.287282         37.097389
# 1        11.482036         21.020887        12.997898         22.246150
# 2        16.509796         28.195949        19.164079         33.661301
# 3        25.558109         41.989452        29.625588         47.739157
# 4        25.049516         40.865843        29.511498         47.774547
#
#    hybrid_corner_pct
# 0          65.454545
# 1          69.565217
# 2          60.869565
# 3          43.055556
# 4          50.000000

# %%
df_all.head()
# Out:
#   scenario service_type   wait_min   ride_min  walk_min  total_min  \
# 0     door         door   2.624093  14.006926       0.0  16.631019
# 1     door         door  48.000000  30.000000       0.0  78.000000
# 2     door         door   3.804045  12.389603       0.0  16.193648
# 3     door         door   3.653921   6.470929       0.0  10.124851
# 4     door         door  48.000000  30.000000       0.0  78.000000
#
#   service_date  service_hour  num_vehicles  total_requests
# 0   2025-10-01             0            10              55
# 1   2025-10-01             0            10              55
# 2   2025-10-01             0            10              55
# 3   2025-10-01             0            10              55
# 4   2025-10-01             0            10              55

# %%
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Set the aesthetic style
sns.set_style("whitegrid")
colors = {'door': '#FF6B6B', 'corner': '#4ECDC4', 'hybrid': '#45B7D1'}
order = ['door', 'corner', 'hybrid']

# %%
# Summary Statistic Table

summary_table = df_all.groupby('scenario').agg({
    'wait_min': ['mean', 'median', 'std', 'min', 'max'],
    'ride_min': ['mean', 'median'],
    'walk_min': ['mean', 'max'],
    'total_min': ['mean', 'median', 'std', 'min', 'max']
}).round(2)

print("\n" + summary_table.to_string())

# Save to CSV
summary_table.to_csv('model_comparison_statistics.csv')
print(f"\n✅ Saved statistics table to model_comparison_statistics.csv")

plt.show()
# Out:
#          wait_min                          ride_min        walk_min        total_min
#              mean median    std  min   max     mean median     mean    max      mean median    std   min   max
# scenario
# corner      18.22  10.79  16.58  2.0  48.0    12.91   8.25     4.02  13.87     31.13  20.37  24.58  2.17  78.0
# door        24.09  17.54  17.60  2.0  48.0    16.21  11.79     0.00   0.00     40.29  29.99  25.63  5.01  78.0
# hybrid      21.98  14.71  17.47  2.0  48.0    14.91  10.19     1.54   5.77     36.89  26.31  25.66  2.21  78.0
#
# ✅ Saved statistics table to model_comparison_statistics.csv
